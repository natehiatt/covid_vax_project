# %%
import pandas as pd

# %%
census_race = pd.read_csv('../data/cc-est2022-all.csv', encoding="latin-1")
census_age = pd.read_csv('../data/cc-est2022-agesex-all.csv')
deaths = pd.read_csv('../data/Provisional_COVID-19_Deaths_by_County__and_Race_and_Hispanic_Origin_20240102.csv')
vaccinations = pd.read_csv('../data/COVID-19_Vaccinations_by_County.csv')
election = pd.read_csv('../data/2020_US_County_Level_Presidential_Results.csv')

population = pd.read_excel('../data/PopulationEstimates.xlsx')
education = pd.read_excel('../data/Education.xlsx')
unemployment = pd.read_excel('../data/Unemployment.xlsx')
poverty = pd.read_excel('../data/PovertyEstimates.xlsx')

# %%
deaths.head()
# Out:
#    Data as of  Start Date    End Date State                   County Name  \
# 0  09/27/2023  01/01/2020  09/23/2023    AK        Anchorage Municipality
# 1  09/27/2023  01/01/2020  09/23/2023    AK        Anchorage Municipality
# 2  09/27/2023  01/01/2020  09/23/2023    AK        Anchorage Municipality
# 3  09/27/2023  01/01/2020  09/23/2023    AK  Fairbanks North Star Borough
# 4  09/27/2023  01/01/2020  09/23/2023    AK  Fairbanks North Star Borough
#
#    Urban Rural Code  FIPS State  FIPS County  FIPS Code  \
# 0                 3           2           20       2020
# 1                 3           2           20       2020
# 2                 3           2           20       2020
# 3                 4           2           90       2090
# 4                 4           2           90       2090
#
#                               Indicator  ...  COVID-19 Deaths  \
# 0  Distribution of all-cause deaths (%)  ...              787
# ...

# %% [markdown]
# ## Connecticut Census Data Reconcilliation

# %% [markdown]
# Fairfield:
# - White:
# - Black:
# - Amer Indian:
# - AAPI
#
#
#
# Hartford

# %% [markdown]
# ## Deaths

# %%
deaths['Data as of'].value_counts()
# Out:
# 09/27/2023    3687
# Name: Data as of, dtype: int64

# %%
deaths.head()
# Out:
#    Data as of  Start Date    End Date State                   County Name  \
# 0  09/27/2023  01/01/2020  09/23/2023    AK        Anchorage Municipality
# 1  09/27/2023  01/01/2020  09/23/2023    AK        Anchorage Municipality
# 2  09/27/2023  01/01/2020  09/23/2023    AK        Anchorage Municipality
# 3  09/27/2023  01/01/2020  09/23/2023    AK  Fairbanks North Star Borough
# 4  09/27/2023  01/01/2020  09/23/2023    AK  Fairbanks North Star Borough
#
#    Urban Rural Code  FIPS State  FIPS County  FIPS Code  \
# 0                 3           2           20       2020
# 1                 3           2           20       2020
# 2                 3           2           20       2020
# 3                 4           2           90       2090
# 4                 4           2           90       2090
#
#                               Indicator  ...  COVID-19 Deaths  \
# 0  Distribution of all-cause deaths (%)  ...              787
# ...

# %%
census.head()
# Out:
#    SUMLEV  STATE  COUNTY   STNAME         CTYNAME  YEAR  AGEGRP  TOT_POP  \
# 0      50      1       1  Alabama  Autauga County     1       0    58802
# 1      50      1       1  Alabama  Autauga County     1       1     3443
# 2      50      1       1  Alabama  Autauga County     1       2     3613
# 3      50      1       1  Alabama  Autauga County     1       3     4131
# 4      50      1       1  Alabama  Autauga County     1       4     3963
#
#    TOT_MALE  TOT_FEMALE  ...  HWAC_MALE  HWAC_FEMALE  HBAC_MALE  HBAC_FEMALE  \
# 0     28761       30041  ...        854          734        112           97
# 1      1790        1653  ...         83           54         14            9
# 2      1849        1764  ...         81           68          5            8
# 3      2121        2010  ...         81           81         10           10
# 4      2003        1960  ...         72           70          8            9
#
# ...

# %%
census.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 238944 entries, 0 to 238943
# Data columns (total 80 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   SUMLEV        238944 non-null  int64
#  1   STATE         238944 non-null  int64
#  2   COUNTY        238944 non-null  int64
#  3   STNAME        238944 non-null  object
#  4   CTYNAME       238944 non-null  object
#  5   YEAR          238944 non-null  int64
#  6   AGEGRP        238944 non-null  int64
#  7   TOT_POP       238944 non-null  int64
#  8   TOT_MALE      238944 non-null  int64
#  9   TOT_FEMALE    238944 non-null  int64
#  10  WA_MALE       238944 non-null  int64
#  11  WA_FEMALE     238944 non-null  int64
#  12  BA_MALE       238944 non-null  int64
#  13  BA_FEMALE     238944 non-null  int64
#  14  IA_MALE       238944 non-null  int64
#  15  IA_FEMALE     238944 non-null  int64
#  16  AA_MALE       238944 non-null  int64
#  17  AA_FEMALE     238944 non-null  int64
# ...

# %%
census.head()
# Out:
#    SUMLEV  STATE  COUNTY   STNAME         CTYNAME  YEAR  AGEGRP  TOT_POP  \
# 0      50      1       1  Alabama  Autauga County     1       0    58802
# 1      50      1       1  Alabama  Autauga County     1       1     3443
# 2      50      1       1  Alabama  Autauga County     1       2     3613
# 3      50      1       1  Alabama  Autauga County     1       3     4131
# 4      50      1       1  Alabama  Autauga County     1       4     3963
#
#    TOT_MALE  TOT_FEMALE  ...  HWAC_MALE  HWAC_FEMALE  HBAC_MALE  HBAC_FEMALE  \
# 0     28761       30041  ...        854          734        112           97
# 1      1790        1653  ...         83           54         14            9
# 2      1849        1764  ...         81           68          5            8
# 3      2121        2010  ...         81           81         10           10
# 4      2003        1960  ...         72           70          8            9
#
# ...

# %%
election['county_fips'].value_counts()
# Out:
# 47103    1
# 28021    1
# 47003    1
# 28017    1
# 31153    1
#         ..
# 13303    1
# 17085    1
# 55041    1
# 17083    1
# 47105    1
# Name: county_fips, Length: 3152, dtype: int64
