# %% [markdown]
# # COVID-19 Vaccinations by County
#
# ## Data Understanding
#
# A full explanation of the different column names can be found [here](https://data.cdc.gov/Vaccinations/COVID-19-Vaccinations-in-the-United-States-County/8xkx-amqh/about_data). Below, we include some of the more important labels.
#
# * [MMWR Week](https://ndc.services.cdc.gov/wp-content/uploads/MMWR_Week_overview.pdf), under `MMWR_week`, refers to the epidemiological ordering of weeks of the year, starting on Sunday and going until Saturday. These weeks are generally numbered 1-52.
# * `Completeness_pct` corresponds to "the proportion of people with a completed primary series whose Federal Information Processing Standards (FIPS) code is reported and matches a valid county FIPS code in the jurisdiction."
#     * Someone has completed their **primary series** if they have received a "second dose of a two-dose vaccine or one dose of a single-dose vaccine."
# * There are then a number of different age brackets: the total number and percentage of individuals vaccinated who are above the ages of 5, 12, 18, and 64. So, for example, we have `Administered_Dose1_Recip`; the percentage form of that, `Administered_Dose1_Pop_Pct`; the raw numbers of those over 5 years old, `Administered_Dose1_Recip_5Plus`, and so on.
# * `Booster_Doses` indicates the number of individuals who have completed a primary series and received a booster dose.
#
# * `SVI` refers to the [social vulnerability index](https://www.atsdr.cdc.gov/placeandhealth/svi/index.html).
# * `Metro_status` tells us whether someone lives within a metro area. We have a number of columns normalizing our data against both SVI and metro status.
# * `Census2019` and associated columns bring over data from the 2019 census.
# * We also have data about those receiving the bivalent booster (authorized by the FDA [late summer 2022](https://www.fda.gov/news-events/press-announcements/coronavirus-covid-19-update-fda-authorizes-moderna-pfizer-biontech-bivalent-covid-19-vaccines-use)), although this data only appears in age-binned categories.
#
#
# ---
#
# Other useful information and links
# * [FIPS codes](https://www.census.gov/programs-surveys/geography/guidance/geo-identifiers.html#ti1187912100)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

census_race = pd.read_csv('../data/cc-est2022-all.csv', encoding="latin-1")
census_age = pd.read_csv('../data/cc-est2022-agesex-all.csv')
deaths = pd.read_csv('../data/Provisional_COVID-19_Deaths_by_County__and_Race_and_Hispanic_Origin_20240102.csv')
vaccinations = pd.read_csv('../data/COVID-19_Vaccinations_by_County.csv')
election = pd.read_csv('../data/2020_US_County_Level_Presidential_Results.csv')

education = pd.read_excel('../data/Education.xlsx')
poverty = pd.read_excel('../data/PovertyEstimates.xlsx')
# Out:
# /Users/shelleywang/anaconda3/envs/learn-env/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3145: DtypeWarning: Columns (1) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
vaccinations.groupby(by="Recip_State")["Recip_County"].value_counts()

# Note the "Unknown County"
# Out:
# Recip_State  Recip_County
# AK           Aleutians East Borough        598
#              Aleutians West Census Area    598
#              Anchorage Municipality        598
#              Bethel Census Area            598
#              Bristol Bay Borough           598
#                                           ...
# WY           Teton County                  598
#              Uinta County                  598
#              Washakie County               598
#              Weston County                 598
#              Unknown County                595
# Name: Recip_County, Length: 3284, dtype: int64

# %%
vaccinations["Recip_State"].value_counts().__len__()
# Out:
# 60

# %%
vaccinations["Recip_State"].value_counts()
# Out:
# TX     152177
# GA      95677
# VA      80130
# KY      72356
# MO      69365
# KS      63385
# IL      61592
# NC      60396
# IA      59797
# TN      57405
# NE      56209
# IN      55611
# OH      53219
# MN      52622
# MI      50230
# MS      49631
# PR      47238
# OK      46641
# AR      45445
# WI      43652
# PA      40662
# FL      40661
# AL      40660
# SD      40064
# CO      38867
# LA      38867
# NY      37672
# CA      35279
# MT      34083
# WV      33484
# ND      32290
# SC      28104
# ID      26907
# WA      23917
# OR      22122
# NM      20329
# UT      17937
# AK      17936
# MD      14947
# WY      14349
# NJ      13153
# NV      10761
# ME      10163
# AZ       9565
# VT       8968
# MA       8967
# NH       6575
# CT       5379
# RI       3585
# HI       3264
# DE       2389
# VI       2382
# DC       1192
# GU       1191
# FM        594
# MP        591
# AS        589
# PW        588
# MH        581
# UNK       308
# Name: Recip_State, dtype: int64

# %%
# Removing PR (Puerto Rico), GU (Guam), and VI (Virgin Islands)
vaccinations = vaccinations[(vaccinations["Recip_State"] != "PR") & (vaccinations["Recip_State"] != "GU") & (vaccinations["Recip_State"] != "VI")]
vaccinations["Recip_State"].value_counts().__len__()
# Out:
# 57

# %%
def drop_terrs(df, state):
    df = df[(df[state] != "PR") & (df[state] != "GU") & (df[state] != "VI") & (df[state] != "AK")]
    return df


def County_with_State(df, county, state):
    df["County_with_State"] = df[county] + ", " + df[state]

# %%
# Removing unknown counties
vaccinations = vaccinations[vaccinations["Recip_County"] != "Unknown County"]

County_with_State(vaccinations, "Recip_County", "Recip_State")
vaccinations["County_with_State"].value_counts()

# Leaves us with 3142 unique counties, each with 598 entries.
# Out:
# Carroll County, IN       598
# Jefferson County, CO     598
# Lake County, OR          598
# Lewis County, NY         598
# Dyer County, TN          598
#                         ...
# Kauai County, HI         598
# Deer Lodge County, MT    598
# Saginaw County, MI       598
# Wayne County, UT         598
# Lancaster County, VA     598
# Name: County_with_State, Length: 3142, dtype: int64

# %%
vaccinations
# Out:
#                Date   FIPS  MMWR_week      Recip_County Recip_State  \
# 0        05/10/2023  55129         19   Washburn County          WI
# 1        05/10/2023  19173         19     Taylor County          IA
# 2        05/10/2023  36059         19     Nassau County          NY
# 3        05/10/2023  48281         19   Lampasas County          TX
# 4        05/10/2023  26145         19    Saginaw County          MI
# ...             ...    ...        ...               ...         ...
# 1962776  12/13/2020  39001         51      Adams County          OH
# 1962777  12/13/2020  18061         51   Harrison County          IN
# 1962778  12/13/2020  48321         51  Matagorda County          TX
# 1962779  12/13/2020  54073         51  Pleasants County          WV
# 1962780  12/13/2020  26061         51   Houghton County          MI
#
#          Completeness_pct  Administered_Dose1_Recip  \
# 0                    96.7                   11123.0
# 1                    97.3                    3149.0
# 2                    97.5                 1391226.0
# 3                    98.9                   11678.0
# 4                    94.0                  104075.0
# ...                   ...                       ...
# 1962776               0.0                       0.0
# 1962777               0.0                       0.0
# 1962778               0.0                       0.0
# 1962779               0.0                       0.0
# 1962780               0.0                       0.0
#
#          Administered_Dose1_Pop_Pct  Administered_Dose1_Recip_5Plus  \
# 0                              70.8                         11097.0
# 1                              51.4                          3145.0
# 2                              95.0                       1384503.0
# 3                              54.5                         11660.0
# 4                              54.6                             NaN
# ...                             ...                             ...
# 1962776                         0.0                             NaN
# 1962777                         0.0                             NaN
# 1962778                         0.0                             NaN
# 1962779                         0.0                             NaN
# 1962780                         0.0                             NaN
#
#          Administered_Dose1_Recip_5PlusPop_Pct  ...  Census2019_65PlusPop  \
# 0                                         73.9  ...                4304.0
# 1                                         55.0  ...                1392.0
# 2                                         95.0  ...              246690.0
# 3                                         57.4  ...                4322.0
# 4                                          NaN  ...               37414.0
# ...                                        ...  ...                   ...
# 1962776                                    NaN  ...                   NaN
# 1962777                                    NaN  ...                   NaN
# 1962778                                    NaN  ...                   NaN
# 1962779                                    NaN  ...                   NaN
# 1962780                                    NaN  ...                   NaN
#
#          Bivalent_Booster_5Plus  Bivalent_Booster_5Plus_Pop_Pct  \
# 0                        3978.0                            26.5
# 1                         841.0                            14.7
# 2                      236202.0                            18.4
# 3                        1951.0                             9.6
# 4                       15618.0                             8.7
# ...                         ...                             ...
# 1962776                     NaN                             NaN
# 1962777                     NaN                             NaN
# 1962778                     NaN                             NaN
# 1962779                     NaN                             NaN
# 1962780                     NaN                             NaN
#
#          Bivalent_Booster_12Plus  Bivalent_Booster_12Plus_Pop_Pct  \
# 0                         3955.0                             28.6
# 1                          841.0                             16.3
# 2                       231748.0                             19.8
# 3                         1947.0                             10.5
# 4                        15448.0                              9.4
# ...                          ...                              ...
# 1962776                      NaN                              NaN
# 1962777                      NaN                              NaN
# 1962778                      NaN                              NaN
# 1962779                      NaN                              NaN
# 1962780                      NaN                              NaN
#
#          Bivalent_Booster_18Plus  Bivalent_Booster_18Plus_Pop_Pct  \
# 0                         3899.0                             30.6
# 1                          834.0                             17.8
# 2                       224931.0                             21.1
# 3                         1925.0                             11.5
# 4                        15112.0                             10.1
# ...                          ...                              ...
# 1962776                      NaN                              NaN
# 1962777                      NaN                              NaN
# 1962778                      NaN                              NaN
# 1962779                      NaN                              NaN
# 1962780                      NaN                              NaN
#
#          Bivalent_Booster_65Plus  Bivalent_Booster_65Plus_Pop_Pct  \
# 0                         2588.0                             60.1
# 1                          588.0                             42.2
# 2                       109947.0                             44.6
# 3                         1229.0                             28.4
# 4                         7921.0                             21.2
# ...                          ...                              ...
# 1962776                      NaN                              NaN
# 1962777                      NaN                              NaN
# 1962778                      NaN                              NaN
# 1962779                      NaN                              NaN
# 1962780                      NaN                              NaN
#
#             County_with_State
# 0         Washburn County, WI
# 1           Taylor County, IA
# 2           Nassau County, NY
# 3         Lampasas County, TX
# 4          Saginaw County, MI
# ...                       ...
# 1962776      Adams County, OH
# 1962777   Harrison County, IN
# 1962778  Matagorda County, TX
# 1962779  Pleasants County, WV
# 1962780   Houghton County, MI
#
# [1878916 rows x 81 columns]

# %%
# Only using year-end dates for 2021 and 2022, and most recent available data for 2023.
# 05/10/2023; 12/28/2022; 12/31/2021

vaccinations = vaccinations[(vaccinations["Date"] == "05/10/2023")]
vaccinations
# And we're left with 3113 rows, corresponding to 1 entry per county.
# Out:
#             Date   FIPS  MMWR_week       Recip_County Recip_State  \
# 0     05/10/2023  55129         19    Washburn County          WI
# 1     05/10/2023  19173         19      Taylor County          IA
# 2     05/10/2023  36059         19      Nassau County          NY
# 3     05/10/2023  48281         19    Lampasas County          TX
# 4     05/10/2023  26145         19     Saginaw County          MI
# ...          ...    ...        ...                ...         ...
# 3278  05/10/2023  29153         19       Ozark County          MO
# 3279  05/10/2023  46065         19      Hughes County          SD
# 3280  05/10/2023  26027         19        Cass County          MI
# 3281  05/10/2023  32001         19   Churchill County          NV
# 3282  05/10/2023  12113         19  Santa Rosa County          FL
#
#       Completeness_pct  Administered_Dose1_Recip  Administered_Dose1_Pop_Pct  \
# 0                 96.7                   11123.0                        70.8
# 1                 97.3                    3149.0                        51.4
# 2                 97.5                 1391226.0                        95.0
# 3                 98.9                   11678.0                        54.5
# 4                 94.0                  104075.0                        54.6
# ...                ...                       ...                         ...
# 3278              91.3                    3762.0                        41.0
# 3279              96.7                   16373.0                        93.4
# 3280              94.0                   26815.0                        51.8
# 3281              95.1                   16252.0                        65.2
# 3282              98.6                  124706.0                        67.7
#
#       Administered_Dose1_Recip_5Plus  Administered_Dose1_Recip_5PlusPop_Pct  \
# 0                            11097.0                                   73.9
# 1                             3145.0                                   55.0
# 2                          1384503.0                                   95.0
# 3                            11660.0                                   57.4
# 4                                NaN                                    NaN
# ...                              ...                                    ...
# 3278                          3760.0                                   42.9
# 3279                         16308.0                                   95.0
# 3280                             NaN                                    NaN
# 3281                         16164.0                                   69.5
# 3282                        124418.0                                   71.5
#
#       ...  Census2019_65PlusPop  Bivalent_Booster_5Plus  \
# 0     ...                4304.0                  3978.0
# 1     ...                1392.0                   841.0
# 2     ...              246690.0                236202.0
# 3     ...                4322.0                  1951.0
# 4     ...               37414.0                 15618.0
# ...   ...                   ...                     ...
# 3278  ...                2684.0                   732.0
# 3279  ...                3158.0                  3659.0
# 3280  ...               11149.0                  3330.0
# 3281  ...                4759.0                  2576.0
# 3282  ...               30121.0                 15546.0
#
#       Bivalent_Booster_5Plus_Pop_Pct  Bivalent_Booster_12Plus  \
# 0                               26.5                   3955.0
# 1                               14.7                    841.0
# 2                               18.4                 231748.0
# 3                                9.6                   1947.0
# 4                                8.7                  15448.0
# ...                              ...                      ...
# 3278                             8.4                    730.0
# 3279                            22.4                   3601.0
# 3280                             6.8                   3293.0
# 3281                            11.1                   2544.0
# 3282                             8.9                  15422.0
#
#       Bivalent_Booster_12Plus_Pop_Pct  Bivalent_Booster_18Plus  \
# 0                                28.6                   3899.0
# 1                                16.3                    834.0
# 2                                19.8                 224931.0
# 3                                10.5                   1925.0
# 4                                 9.4                  15112.0
# ...                               ...                      ...
# 3278                              9.0                    724.0
# 3279                             24.7                   3499.0
# 3280                              7.3                   3219.0
# 3281                             12.1                   2475.0
# 3282                              9.7                  15134.0
#
#       Bivalent_Booster_18Plus_Pop_Pct  Bivalent_Booster_65Plus  \
# 0                                30.6                   2588.0
# 1                                17.8                    588.0
# 2                                21.1                 109947.0
# 3                                11.5                   1229.0
# 4                                10.1                   7921.0
# ...                               ...                      ...
# 3278                              9.8                    512.0
# 3279                             26.3                   1857.0
# 3280                              7.8                   1822.0
# 3281                             12.9                   1439.0
# 3282                             10.5                   8277.0
#
#       Bivalent_Booster_65Plus_Pop_Pct      County_with_State
# 0                                60.1    Washburn County, WI
# 1                                42.2      Taylor County, IA
# 2                                44.6      Nassau County, NY
# 3                                28.4    Lampasas County, TX
# 4                                21.2     Saginaw County, MI
# ...                               ...                    ...
# 3278                             19.1       Ozark County, MO
# 3279                             58.8      Hughes County, SD
# 3280                             16.3        Cass County, MI
# 3281                             30.2   Churchill County, NV
# 3282                             27.5  Santa Rosa County, FL
#
# [3142 rows x 81 columns]

# %%
# fig, ax = plt.subplots(figsize=(10, 5))
# ax = saginaw_mi.plot(x="Date", y="Series_Complete_Pop_Pct", ax=ax)

# %% [markdown]
# ## Presidential Election Data

# %%
election.head()
# Out:
#   state_name  county_fips     county_name  votes_gop  votes_dem  total_votes  \
# 0    Alabama         1001  Autauga County      19838       7503        27770
# 1    Alabama         1003  Baldwin County      83544      24578       109679
# 2    Alabama         1005  Barbour County       5622       4816        10518
# 3    Alabama         1007     Bibb County       7525       1986         9595
# 4    Alabama         1009   Blount County      24711       2640        27588
#
#     diff   per_gop   per_dem  per_point_diff
# 0  12335  0.714368  0.270184        0.444184
# 1  58966  0.761714  0.224090        0.537623
# 2    806  0.534512  0.457882        0.076631
# 3   5539  0.784263  0.206983        0.577280
# 4  22071  0.895716  0.095694        0.800022

# %%
# adding a state_abbrev column
state_abbrevs = {
    "Alabama": "AL",
    "Alaska": "AK",
    "Arizona": "AZ",
    "Arkansas": "AR",
    "California": "CA",
    "Colorado": "CO",
    "Connecticut": "CT",
    "Delaware": "DE",
    "Florida": "FL",
    "Georgia": "GA",
    "Hawaii": "HI",
    "Idaho": "ID",
    "Illinois": "IL",
    "Indiana": "IN",
    "Iowa": "IA",
    "Kansas": "KS",
    "Kentucky": "KY",
    "Louisiana": "LA",
    "Maine": "ME",
    "Maryland": "MD",
    "Massachusetts": "MA",
    "Michigan": "MI",
    "Minnesota": "MN",
    "Mississippi": "MS",
    "Missouri": "MO",
    "Montana": "MT",
    "Nebraska": "NE",
    "Nevada": "NV",
    "New Hampshire": "NH",
    "New Jersey": "NJ",
    "New Mexico": "NM",
    "New York": "NY",
    "North Carolina": "NC",
    "North Dakota": "ND",
    "Ohio": "OH",
    "Oklahoma": "OK",
    "Oregon": "OR",
    "Pennsylvania": "PA",
    "Rhode Island": "RI",
    "South Carolina": "SC",
    "South Dakota": "SD",
    "Tennessee": "TN",
    "Texas": "TX",
    "Utah": "UT",
    "Vermont": "VT",
    "Virginia": "VA",
    "Washington": "WA",
    "West Virginia": "WV",
    "Wisconsin": "WI",
    "Wyoming": "WY",
    "District of Columbia": "DC",
    "American Samoa": "AS",
    "Guam": "GU",
    "Northern Mariana Islands": "MP",
    "Puerto Rico": "PR",
    "United States Minor Outlying Islands": "UM",
    "U.S. Virgin Islands": "VI",
}

election["state_abbrev"] = election["state_name"].map(state_abbrevs)
election.head()
# Out:
#   state_name  county_fips     county_name  votes_gop  votes_dem  total_votes  \
# 0    Alabama         1001  Autauga County      19838       7503        27770
# 1    Alabama         1003  Baldwin County      83544      24578       109679
# 2    Alabama         1005  Barbour County       5622       4816        10518
# 3    Alabama         1007     Bibb County       7525       1986         9595
# 4    Alabama         1009   Blount County      24711       2640        27588
#
#     diff   per_gop   per_dem  per_point_diff state_abbrev
# 0  12335  0.714368  0.270184        0.444184           AL
# 1  58966  0.761714  0.224090        0.537623           AL
# 2    806  0.534512  0.457882        0.076631           AL
# 3   5539  0.784263  0.206983        0.577280           AL
# 4  22071  0.895716  0.095694        0.800022           AL

# %%
election["state_name"].value_counts().__len__()
# Out:
# 51

# %%
election.groupby(by="state_abbrev")["county_name"].value_counts()
# Out:
# state_abbrev  county_name
# AK            District 1           1
#               District 10          1
#               District 11          1
#               District 12          1
#               District 13          1
#                                   ..
# WY            Sweetwater County    1
#               Teton County         1
#               Uinta County         1
#               Washakie County      1
#               Weston County        1
# Name: county_name, Length: 3152, dtype: int64

# %%
election
# Out:
#      state_name  county_fips        county_name  votes_gop  votes_dem  \
# 0       Alabama         1001     Autauga County      19838       7503
# 1       Alabama         1003     Baldwin County      83544      24578
# 2       Alabama         1005     Barbour County       5622       4816
# 3       Alabama         1007        Bibb County       7525       1986
# 4       Alabama         1009      Blount County      24711       2640
# ...         ...          ...                ...        ...        ...
# 3147    Wyoming        56037  Sweetwater County      12229       3823
# 3148    Wyoming        56039       Teton County       4341       9848
# 3149    Wyoming        56041       Uinta County       7496       1591
# 3150    Wyoming        56043    Washakie County       3245        651
# 3151    Wyoming        56045      Weston County       3107        360
#
#       total_votes   diff   per_gop   per_dem  per_point_diff state_abbrev
# 0           27770  12335  0.714368  0.270184        0.444184           AL
# 1          109679  58966  0.761714  0.224090        0.537623           AL
# 2           10518    806  0.534512  0.457882        0.076631           AL
# 3            9595   5539  0.784263  0.206983        0.577280           AL
# 4           27588  22071  0.895716  0.095694        0.800022           AL
# ...           ...    ...       ...       ...             ...          ...
# 3147        16603   8406  0.736554  0.230260        0.506294           WY
# 3148        14677  -5507  0.295769  0.670982       -0.375213           WY
# 3149         9402   5905  0.797277  0.169219        0.628058           WY
# 3150         4012   2594  0.808824  0.162263        0.646560           WY
# 3151         3542   2747  0.877188  0.101637        0.775551           WY
#
# [3152 rows x 11 columns]

# %%
election["votes_third_party"] = election["total_votes"] - election["votes_dem"] - election["votes_gop"]
election["per_third_party"] = round(100 * election["votes_third_party"] / election["total_votes"], 1)

# %%
election['per_gop'] = round(100 * election['per_gop'], 1)
election['per_dem'] = round(100 * election['per_dem'], 1)

# %%
# Dropping PR (Puerto Rico), GU (Guam), and VI (Virgin Islands)
# This doesn't actually change the total number of counties.
election = election[(election["state_abbrev"] != "PR") & (election["state_abbrev"] != "GU") & (election["state_abbrev"] != "VI")]
election.groupby(by="state_abbrev")["county_name"].value_counts()
# Out:
# state_abbrev  county_name
# AK            District 1           1
#               District 10          1
#               District 11          1
#               District 12          1
#               District 13          1
#                                   ..
# WY            Sweetwater County    1
#               Teton County         1
#               Uinta County         1
#               Washakie County      1
#               Weston County        1
# Name: county_name, Length: 3152, dtype: int64

# %%
County_with_State(election, "county_name", "state_abbrev")
election["County_with_State"].value_counts()
# Out:
# Chase County, NE         1
# Taylor County, KY        1
# Knox County, TN          1
# Hopkins County, KY       1
# Ravalli County, MT       1
#                         ..
# Troup County, GA         1
# Montgomery County, IA    1
# Rock County, WI          1
# Gaston County, NC        1
# Ross County, OH          1
# Name: County_with_State, Length: 3152, dtype: int64

# %%
# Function to automatically compare difference in counties:
def check_overlap(df1, df2, column):
    vc1 = pd.DataFrame(df1[column])
    vc2 = pd.DataFrame(df2[column])
    combined = pd.merge(vc1, vc2, how="outer", indicator=True)
    combined_right = combined[combined["_merge"] == "right_only"]
    combined_left = combined[combined["_merge"] == "left_only"]
    return combined_right.value_counts(), combined_left.value_counts()

check_overlap(election, vaccinations, "County_with_State")
# Out:
# (County_with_State                      _merge
#  Yukon-Koyukuk Census Area, AK          right_only    1
#  Yakutat City and Borough, AK           right_only    1
#  Aleutians West Census Area, AK         right_only    1
#  Anchorage Municipality, AK             right_only    1
#  Bethel Census Area, AK                 right_only    1
#  Bristol Bay Borough, AK                right_only    1
#  Denali Borough, AK                     right_only    1
#  Dillingham Census Area, AK             right_only    1
#  Dona Ana County, NM                    right_only    1
#  Fairbanks North Star Borough, AK       right_only    1
#  Haines Borough, AK                     right_only    1
#  Hoonah-Angoon Census Area, AK          right_only    1
#  Juneau City and Borough, AK            right_only    1
#  Kalawao County, HI                     right_only    1
#  Kenai Peninsula Borough, AK            right_only    1
#  Ketchikan Gateway Borough, AK          right_only    1
#  Kodiak Island Borough, AK              right_only    1
#  Kusilvak Census Area, AK               right_only    1
#  La Salle Parish, LA                    right_only    1
#  Lake and Peninsula Borough, AK         right_only    1
#  Matanuska-Susitna Borough, AK          right_only    1
#  Nome Census Area, AK                   right_only    1
#  North Slope Borough, AK                right_only    1
#  Northwest Arctic Borough, AK           right_only    1
#  Petersburg Census Area, AK             right_only    1
#  Prince of Wales-Hyder Census Area, AK  right_only    1
#  Sitka City and Borough, AK             right_only    1
#  Skagway Municipality, AK               right_only    1
#  Southeast Fairbanks Census Area, AK    right_only    1
#  Valdez-Cordova Census Area, AK         right_only    1
#  Wrangell City and Borough, AK          right_only    1
#  Aleutians East Borough, AK             right_only    1
#  dtype: int64,
#  County_with_State    _merge
#  LaSalle Parish, LA   left_only    1
#  District 19, AK      left_only    1
#  District 26, AK      left_only    1
#  District 25, AK      left_only    1
#  District 24, AK      left_only    1
#  District 23, AK      left_only    1
#  District 22, AK      left_only    1
#  District 21, AK      left_only    1
#  District 20, AK      left_only    1
#  District 2, AK       left_only    1
#  District 18, AK      left_only    1
#  Doña Ana County, NM  left_only    1
#  District 17, AK      left_only    1
#  District 16, AK      left_only    1
#  District 15, AK      left_only    1
#  District 14, AK      left_only    1
#  District 13, AK      left_only    1
#  District 12, AK      left_only    1
#  District 11, AK      left_only    1
#  District 10, AK      left_only    1
#  District 27, AK      left_only    1
#  District 28, AK      left_only    1
#  District 29, AK      left_only    1
#  District 3, AK       left_only    1
#  District 9, AK       left_only    1
#  District 8, AK       left_only    1
#  District 7, AK       left_only    1
#  District 6, AK       left_only    1
#  District 5, AK       left_only    1
#  District 40, AK      left_only    1
#  District 4, AK       left_only    1
#  District 39, AK      left_only    1
#  District 38, AK      left_only    1
#  District 37, AK      left_only    1
#  District 36, AK      left_only    1
#  District 35, AK      left_only    1
#  District 34, AK      left_only    1
#  District 33, AK      left_only    1
#  District 32, AK      left_only    1
#  District 31, AK      left_only    1
#  District 30, AK      left_only    1
#  District 1, AK       left_only    1
#  dtype: int64)

# %% [markdown]
# "Unlike other states within the United States, Alaska does not administer its presidential elections at the county-level but rather at the lower chamber legislative district, or the House District."[link](https://github.com/tonmcg/US_County_Level_Election_Results_08-20?tab=readme-ov-file#alaska)

# %%
# Removing Alaska from the dfs:
election = election[election["state_abbrev"] != "AK"]
vaccinations = vaccinations[vaccinations["Recip_State"] != "AK"]

# Comparing again:
check_overlap(election, vaccinations, "County_with_State")
# Out:
# (County_with_State    _merge
#  La Salle Parish, LA  right_only    1
#  Kalawao County, HI   right_only    1
#  Dona Ana County, NM  right_only    1
#  dtype: int64,
#  County_with_State    _merge
#  LaSalle Parish, LA   left_only    1
#  Doña Ana County, NM  left_only    1
#  dtype: int64)

# %%
# Renaming the different county names to match
election["County_with_State"] = election["County_with_State"].replace("Doña Ana County, NM", "Dona Ana County, NM")
election["county_name"] = election["county_name"].replace("Doña Ana County", "Dona Ana County")
election["County_with_State"] = election["County_with_State"].replace("LaSalle Parish, LA", "La Salle Parish, LA")
election["county_name"] = election["county_name"].replace("LaSalle Parish", "La Salle Parish")

# Comparing again:
check_overlap(election, vaccinations, "County_with_State")
# Out:
# (County_with_State   _merge
#  Kalawao County, HI  right_only    1
#  dtype: int64,
#  Series([], dtype: int64))

# %% [markdown]
# # Paring down and combining Election + Vaccination Dataframes

# %%
election
# Out:
#      state_name  county_fips        county_name  votes_gop  votes_dem  \
# 0       Alabama         1001     Autauga County      19838       7503
# 1       Alabama         1003     Baldwin County      83544      24578
# 2       Alabama         1005     Barbour County       5622       4816
# 3       Alabama         1007        Bibb County       7525       1986
# 4       Alabama         1009      Blount County      24711       2640
# ...         ...          ...                ...        ...        ...
# 3147    Wyoming        56037  Sweetwater County      12229       3823
# 3148    Wyoming        56039       Teton County       4341       9848
# 3149    Wyoming        56041       Uinta County       7496       1591
# 3150    Wyoming        56043    Washakie County       3245        651
# 3151    Wyoming        56045      Weston County       3107        360
#
#       total_votes   diff  per_gop  per_dem  per_point_diff state_abbrev  \
# 0           27770  12335     71.4     27.0        0.444184           AL
# 1          109679  58966     76.2     22.4        0.537623           AL
# 2           10518    806     53.5     45.8        0.076631           AL
# 3            9595   5539     78.4     20.7        0.577280           AL
# 4           27588  22071     89.6      9.6        0.800022           AL
# ...           ...    ...      ...      ...             ...          ...
# 3147        16603   8406     73.7     23.0        0.506294           WY
# 3148        14677  -5507     29.6     67.1       -0.375213           WY
# 3149         9402   5905     79.7     16.9        0.628058           WY
# 3150         4012   2594     80.9     16.2        0.646560           WY
# 3151         3542   2747     87.7     10.2        0.775551           WY
#
#       votes_third_party  per_third_party      County_with_State
# 0                   429              1.5     Autauga County, AL
# 1                  1557              1.4     Baldwin County, AL
# 2                    80              0.8     Barbour County, AL
# 3                    84              0.9        Bibb County, AL
# 4                   237              0.9      Blount County, AL
# ...                 ...              ...                    ...
# 3147                551              3.3  Sweetwater County, WY
# 3148                488              3.3       Teton County, WY
# 3149                315              3.4       Uinta County, WY
# 3150                116              2.9    Washakie County, WY
# 3151                 75              2.1      Weston County, WY
#
# [3112 rows x 14 columns]

# %%
election = election[["per_gop", "per_dem", "per_third_party", "County_with_State"]]
election
# Out:
#       per_gop  per_dem  per_third_party      County_with_State
# 0        71.4     27.0              1.5     Autauga County, AL
# 1        76.2     22.4              1.4     Baldwin County, AL
# 2        53.5     45.8              0.8     Barbour County, AL
# 3        78.4     20.7              0.9        Bibb County, AL
# 4        89.6      9.6              0.9      Blount County, AL
# ...       ...      ...              ...                    ...
# 3147     73.7     23.0              3.3  Sweetwater County, WY
# 3148     29.6     67.1              3.3       Teton County, WY
# 3149     79.7     16.9              3.4       Uinta County, WY
# 3150     80.9     16.2              2.9    Washakie County, WY
# 3151     87.7     10.2              2.1      Weston County, WY
#
# [3112 rows x 4 columns]

# %%
vaccinations
# Out:
#             Date   FIPS  MMWR_week       Recip_County Recip_State  \
# 0     05/10/2023  55129         19    Washburn County          WI
# 1     05/10/2023  19173         19      Taylor County          IA
# 2     05/10/2023  36059         19      Nassau County          NY
# 3     05/10/2023  48281         19    Lampasas County          TX
# 4     05/10/2023  26145         19     Saginaw County          MI
# ...          ...    ...        ...                ...         ...
# 3278  05/10/2023  29153         19       Ozark County          MO
# 3279  05/10/2023  46065         19      Hughes County          SD
# 3280  05/10/2023  26027         19        Cass County          MI
# 3281  05/10/2023  32001         19   Churchill County          NV
# 3282  05/10/2023  12113         19  Santa Rosa County          FL
#
#       Completeness_pct  Administered_Dose1_Recip  Administered_Dose1_Pop_Pct  \
# 0                 96.7                   11123.0                        70.8
# 1                 97.3                    3149.0                        51.4
# 2                 97.5                 1391226.0                        95.0
# 3                 98.9                   11678.0                        54.5
# 4                 94.0                  104075.0                        54.6
# ...                ...                       ...                         ...
# 3278              91.3                    3762.0                        41.0
# 3279              96.7                   16373.0                        93.4
# 3280              94.0                   26815.0                        51.8
# 3281              95.1                   16252.0                        65.2
# 3282              98.6                  124706.0                        67.7
#
#       Administered_Dose1_Recip_5Plus  Administered_Dose1_Recip_5PlusPop_Pct  \
# 0                            11097.0                                   73.9
# 1                             3145.0                                   55.0
# 2                          1384503.0                                   95.0
# 3                            11660.0                                   57.4
# 4                                NaN                                    NaN
# ...                              ...                                    ...
# 3278                          3760.0                                   42.9
# 3279                         16308.0                                   95.0
# 3280                             NaN                                    NaN
# 3281                         16164.0                                   69.5
# 3282                        124418.0                                   71.5
#
#       ...  Census2019_65PlusPop  Bivalent_Booster_5Plus  \
# 0     ...                4304.0                  3978.0
# 1     ...                1392.0                   841.0
# 2     ...              246690.0                236202.0
# 3     ...                4322.0                  1951.0
# 4     ...               37414.0                 15618.0
# ...   ...                   ...                     ...
# 3278  ...                2684.0                   732.0
# 3279  ...                3158.0                  3659.0
# 3280  ...               11149.0                  3330.0
# 3281  ...                4759.0                  2576.0
# 3282  ...               30121.0                 15546.0
#
#       Bivalent_Booster_5Plus_Pop_Pct  Bivalent_Booster_12Plus  \
# 0                               26.5                   3955.0
# 1                               14.7                    841.0
# 2                               18.4                 231748.0
# 3                                9.6                   1947.0
# 4                                8.7                  15448.0
# ...                              ...                      ...
# 3278                             8.4                    730.0
# 3279                            22.4                   3601.0
# 3280                             6.8                   3293.0
# 3281                            11.1                   2544.0
# 3282                             8.9                  15422.0
#
#       Bivalent_Booster_12Plus_Pop_Pct  Bivalent_Booster_18Plus  \
# 0                                28.6                   3899.0
# 1                                16.3                    834.0
# 2                                19.8                 224931.0
# 3                                10.5                   1925.0
# 4                                 9.4                  15112.0
# ...                               ...                      ...
# 3278                              9.0                    724.0
# 3279                             24.7                   3499.0
# 3280                              7.3                   3219.0
# 3281                             12.1                   2475.0
# 3282                              9.7                  15134.0
#
#       Bivalent_Booster_18Plus_Pop_Pct  Bivalent_Booster_65Plus  \
# 0                                30.6                   2588.0
# 1                                17.8                    588.0
# 2                                21.1                 109947.0
# 3                                11.5                   1229.0
# 4                                10.1                   7921.0
# ...                               ...                      ...
# 3278                              9.8                    512.0
# 3279                             26.3                   1857.0
# 3280                              7.8                   1822.0
# 3281                             12.9                   1439.0
# 3282                             10.5                   8277.0
#
#       Bivalent_Booster_65Plus_Pop_Pct      County_with_State
# 0                                60.1    Washburn County, WI
# 1                                42.2      Taylor County, IA
# 2                                44.6      Nassau County, NY
# 3                                28.4    Lampasas County, TX
# 4                                21.2     Saginaw County, MI
# ...                               ...                    ...
# 3278                             19.1       Ozark County, MO
# 3279                             58.8      Hughes County, SD
# 3280                             16.3        Cass County, MI
# 3281                             30.2   Churchill County, NV
# 3282                             27.5  Santa Rosa County, FL
#
# [3113 rows x 81 columns]

# %%
"""
Filter by 
* Date
* County_with_State
* Completeness_pct
* Metro_status
* SVI_CTGY
* Census2019
"""

vaccinations = vaccinations[["Date", "County_with_State", "Completeness_pct", "Metro_status", "SVI_CTGY", "Census2019"]]
vaccinations
# Out:
#             Date      County_with_State  Completeness_pct Metro_status  \
# 0     05/10/2023    Washburn County, WI              96.7    Non-metro
# 1     05/10/2023      Taylor County, IA              97.3    Non-metro
# 2     05/10/2023      Nassau County, NY              97.5        Metro
# 3     05/10/2023    Lampasas County, TX              98.9        Metro
# 4     05/10/2023     Saginaw County, MI              94.0        Metro
# ...          ...                    ...               ...          ...
# 3278  05/10/2023       Ozark County, MO              91.3    Non-metro
# 3279  05/10/2023      Hughes County, SD              96.7    Non-metro
# 3280  05/10/2023        Cass County, MI              94.0        Metro
# 3281  05/10/2023   Churchill County, NV              95.1    Non-metro
# 3282  05/10/2023  Santa Rosa County, FL              98.6        Metro
#
#      SVI_CTGY  Census2019
# 0           A     15720.0
# 1           A      6121.0
# 2           B   1356924.0
# 3           C     21428.0
# 4           C    190539.0
# ...       ...         ...
# 3278        B      9174.0
# 3279        B     17526.0
# 3280        A     51787.0
# 3281        C     24909.0
# 3282        B    184313.0
#
# [3113 rows x 6 columns]

# %%
# Making the combined df

df = pd.merge(election, vaccinations, how="inner", on="County_with_State")
df
# Out:
#       per_gop  per_dem  per_third_party      County_with_State        Date  \
# 0        71.4     27.0              1.5     Autauga County, AL  05/10/2023
# 1        76.2     22.4              1.4     Baldwin County, AL  05/10/2023
# 2        53.5     45.8              0.8     Barbour County, AL  05/10/2023
# 3        78.4     20.7              0.9        Bibb County, AL  05/10/2023
# 4        89.6      9.6              0.9      Blount County, AL  05/10/2023
# ...       ...      ...              ...                    ...         ...
# 3107     73.7     23.0              3.3  Sweetwater County, WY  05/10/2023
# 3108     29.6     67.1              3.3       Teton County, WY  05/10/2023
# 3109     79.7     16.9              3.4       Uinta County, WY  05/10/2023
# 3110     80.9     16.2              2.9    Washakie County, WY  05/10/2023
# 3111     87.7     10.2              2.1      Weston County, WY  05/10/2023
#
#       Completeness_pct Metro_status SVI_CTGY  Census2019
# 0                 92.6        Metro        C     55869.0
# 1                 92.6        Metro        B    223234.0
# 2                 92.6    Non-metro        D     24686.0
# 3                 92.6        Metro        D     22394.0
# 4                 92.6        Metro        C     57826.0
# ...                ...          ...      ...         ...
# 3107              97.1    Non-metro        B     42343.0
# 3108              97.1    Non-metro        A     23464.0
# 3109              97.1    Non-metro        B     20226.0
# 3110              97.1    Non-metro        B      7805.0
# 3111              97.1    Non-metro        A      6927.0
#
# [3112 rows x 9 columns]

# %%
df['County_with_State'].value_counts()
# Out:
# Chase County, NE          1
# Monroe County, IL         1
# Walker County, TX         1
# Gloucester County, NJ     1
# Scott County, MN          1
#                          ..
# Mississippi County, MO    1
# Elliott County, KY        1
# Pawnee County, NE         1
# Holmes County, MS         1
# Ross County, OH           1
# Name: County_with_State, Length: 3112, dtype: int64

# %% [markdown]
# # Poverty dataset

# %%
poverty = pd.read_excel('../data/PovertyEstimates.xlsx')

poverty.columns = poverty.iloc[3]
poverty
# Out:
# 3                                             FIPS_Code  Stabr  \
# 0     Source: U.S. Department of Commerce, Bureau of...    NaN
# 1     For definitions of rural classifications, see ...    NaN
# 2     This table was prepared by USDA, Economic Rese...    NaN
# 3                                             FIPS_Code  Stabr
# 4                                                 00000     US
# ...                                                 ...    ...
# 3194                                              56037     WY
# 3195                                              56039     WY
# 3196                                              56041     WY
# 3197                                              56043     WY
# 3198                                              56045     WY
#
# 3             Area_name  Rural-urban_Continuum_Code_2003  \
# 0                   NaN                              NaN
# 1                   NaN                              NaN
# 2                   NaN                              NaN
# 3             Area_name  Rural-urban_Continuum_Code_2003
# 4         United States                              NaN
# ...                 ...                              ...
# 3194  Sweetwater County                                5
# 3195       Teton County                                7
# 3196       Uinta County                                7
# 3197    Washakie County                                7
# 3198      Weston County                                7
#
# 3     Urban_Influence_Code_2003  Rural-urban_Continuum_Code_2013  \
# 0                           NaN                              NaN
# 1                           NaN                              NaN
# 2                           NaN                              NaN
# 3     Urban_Influence_Code_2003  Rural-urban_Continuum_Code_2013
# 4                           NaN                              NaN
# ...                         ...                              ...
# 3194                          8                                5
# 3195                          8                                7
# 3196                          8                                7
# 3197                         11                                7
# 3198                          9                                7
#
# 3     Urban_Influence_Code_ 2013  POVALL_2021  CI90LBALL_2021  CI90UBALL_2021  \
# 0                            NaN          NaN             NaN             NaN
# 1                            NaN          NaN             NaN             NaN
# 2                            NaN          NaN             NaN             NaN
# 3     Urban_Influence_Code_ 2013  POVALL_2021  CI90LBALL_2021  CI90UBALL_2021
# 4                            NaN     41393176        41149497        41636855
# ...                          ...          ...             ...             ...
# 3194                           8         3761            3048            4474
# 3195                           8         1392            1070            1714
# 3196                           8         1917            1457            2377
# 3197                          11          773             579             967
# 3198                           9          666             504             828
#
# 3     ...  CI90UB517P_2021  MEDHHINC_2021  CI90LBINC_2021  CI90UBINC_2021  \
# 0     ...              NaN            NaN             NaN             NaN
# 1     ...              NaN            NaN             NaN             NaN
# 2     ...              NaN            NaN             NaN             NaN
# 3     ...  CI90UB517P_2021  MEDHHINC_2021  CI90LBINC_2021  CI90UBINC_2021
# 4     ...             16.3          69717           69583           69851
# ...   ...              ...            ...             ...             ...
# 3194  ...             11.5          74677           66928           82426
# 3195  ...              6.4         102709           90132          115286
# 3196  ...             12.9          70162           62206           78118
# 3197  ...             15.6          62176           55415           68937
# 3198  ...             14.6          62509           55613           69405
#
# 3     POV04_2021  CI90LB04_2021  CI90UB04_2021  PCTPOV04_2021  CI90LB04P_2021  \
# 0            NaN            NaN            NaN            NaN             NaN
# 1            NaN            NaN            NaN            NaN             NaN
# 2            NaN            NaN            NaN            NaN             NaN
# 3     POV04_2021  CI90LB04_2021  CI90UB04_2021  PCTPOV04_2021  CI90LB04P_2021
# 4        3349149        3299669        3398629           18.3              18
# ...          ...            ...            ...            ...             ...
# 3194         NaN            NaN            NaN            NaN             NaN
# 3195         NaN            NaN            NaN            NaN             NaN
# 3196         NaN            NaN            NaN            NaN             NaN
# 3197         NaN            NaN            NaN            NaN             NaN
# 3198         NaN            NaN            NaN            NaN             NaN
#
# 3     CI90UB04P_2021
# 0                NaN
# 1                NaN
# 2                NaN
# 3     CI90UB04P_2021
# 4               18.6
# ...              ...
# 3194             NaN
# 3195             NaN
# 3196             NaN
# 3197             NaN
# 3198             NaN
#
# [3199 rows x 34 columns]

# %%
poverty.drop(poverty.index[0:5], inplace=True)
poverty = drop_terrs(poverty, "Stabr")
# poverty = poverty[(poverty["Stabr"] != "PR") & (poverty["Stabr"] != "GU") & (poverty["Stabr"] != "VI") & (poverty["Stabr"] != "AK")]
poverty
# Out:
# 3    FIPS_Code Stabr          Area_name Rural-urban_Continuum_Code_2003  \
# 5        01000    AL            Alabama                             NaN
# 6        01001    AL     Autauga County                               2
# 7        01003    AL     Baldwin County                               4
# 8        01005    AL     Barbour County                               6
# 9        01007    AL        Bibb County                               1
# ...        ...   ...                ...                             ...
# 3194     56037    WY  Sweetwater County                               5
# 3195     56039    WY       Teton County                               7
# 3196     56041    WY       Uinta County                               7
# 3197     56043    WY    Washakie County                               7
# 3198     56045    WY      Weston County                               7
#
# 3    Urban_Influence_Code_2003 Rural-urban_Continuum_Code_2013  \
# 5                          NaN                             NaN
# 6                            2                               2
# 7                            5                               3
# 8                            6                               6
# 9                            1                               1
# ...                        ...                             ...
# 3194                         8                               5
# 3195                         8                               7
# 3196                         8                               7
# 3197                        11                               7
# 3198                         9                               7
#
# 3    Urban_Influence_Code_ 2013 POVALL_2021 CI90LBALL_2021 CI90UBALL_2021  \
# 5                           NaN      800848         782169         819527
# 6                             2        6296           4772           7820
# 7                             2       25526          21599          29453
# 8                             6        5089           3773           6405
# 9                             1        4204           3324           5084
# ...                         ...         ...            ...            ...
# 3194                          8        3761           3048           4474
# 3195                          8        1392           1070           1714
# 3196                          8        1917           1457           2377
# 3197                         11         773            579            967
# 3198                          9         666            504            828
#
# 3     ... CI90UB517P_2021 MEDHHINC_2021 CI90LBINC_2021 CI90UBINC_2021  \
# 5     ...            22.5         53990          53218          54762
# 6     ...            20.4         66444          60061          72827
# 7     ...            18.5         65658          60723          70593
# 8     ...            44.6         38649          34308          42990
# 9     ...            35.4         48454          42438          54470
# ...   ...             ...           ...            ...            ...
# 3194  ...            11.5         74677          66928          82426
# 3195  ...             6.4        102709          90132         115286
# 3196  ...            12.9         70162          62206          78118
# 3197  ...            15.6         62176          55415          68937
# 3198  ...            14.6         62509          55613          69405
#
# 3    POV04_2021 CI90LB04_2021 CI90UB04_2021 PCTPOV04_2021 CI90LB04P_2021  \
# 5         71220         66888         75552          25.1           23.6
# 6           NaN           NaN           NaN           NaN            NaN
# 7           NaN           NaN           NaN           NaN            NaN
# 8           NaN           NaN           NaN           NaN            NaN
# 9           NaN           NaN           NaN           NaN            NaN
# ...         ...           ...           ...           ...            ...
# 3194        NaN           NaN           NaN           NaN            NaN
# 3195        NaN           NaN           NaN           NaN            NaN
# 3196        NaN           NaN           NaN           NaN            NaN
# 3197        NaN           NaN           NaN           NaN            NaN
# 3198        NaN           NaN           NaN           NaN            NaN
#
# 3    CI90UB04P_2021
# 5              26.6
# 6               NaN
# 7               NaN
# 8               NaN
# 9               NaN
# ...             ...
# 3194            NaN
# 3195            NaN
# 3196            NaN
# 3197            NaN
# 3198            NaN
#
# [3163 rows x 34 columns]

# %%
County_with_State(poverty, "Area_name", "Stabr")
poverty.head()
# Out:
# <ipython-input-840-3c6bf79f3f30>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["County_with_State"] = df[county] + ", " + df[state]
# 3 FIPS_Code Stabr       Area_name Rural-urban_Continuum_Code_2003  \
# 5     01000    AL         Alabama                             NaN
# 6     01001    AL  Autauga County                               2
# 7     01003    AL  Baldwin County                               4
# 8     01005    AL  Barbour County                               6
# 9     01007    AL     Bibb County                               1
#
# 3 Urban_Influence_Code_2003 Rural-urban_Continuum_Code_2013  \
# 5                       NaN                             NaN
# 6                         2                               2
# 7                         5                               3
# 8                         6                               6
# 9                         1                               1
#
# 3 Urban_Influence_Code_ 2013 POVALL_2021 CI90LBALL_2021 CI90UBALL_2021  ...  \
# 5                        NaN      800848         782169         819527  ...
# 6                          2        6296           4772           7820  ...
# 7                          2       25526          21599          29453  ...
# 8                          6        5089           3773           6405  ...
# 9                          1        4204           3324           5084  ...
#
# 3 MEDHHINC_2021 CI90LBINC_2021 CI90UBINC_2021 POV04_2021 CI90LB04_2021  \
# 5         53990          53218          54762      71220         66888
# 6         66444          60061          72827        NaN           NaN
# 7         65658          60723          70593        NaN           NaN
# 8         38649          34308          42990        NaN           NaN
# 9         48454          42438          54470        NaN           NaN
#
# 3 CI90UB04_2021 PCTPOV04_2021 CI90LB04P_2021 CI90UB04P_2021  \
# 5         75552          25.1           23.6           26.6
# 6           NaN           NaN            NaN            NaN
# 7           NaN           NaN            NaN            NaN
# 8           NaN           NaN            NaN            NaN
# 9           NaN           NaN            NaN            NaN
#
# 3   County_with_State
# 5         Alabama, AL
# 6  Autauga County, AL
# 7  Baldwin County, AL
# 8  Barbour County, AL
# 9     Bibb County, AL
#
# [5 rows x 35 columns]

# %%
check_overlap(df, poverty, "County_with_State")
# Out:
# (County_with_State    _merge
#  Wyoming, WY          right_only    1
#  Wisconsin, WI        right_only    1
#  Massachusetts, MA    right_only    1
#  Maryland, MD         right_only    1
#  Maine, ME            right_only    1
#  Louisiana, LA        right_only    1
#  Lagrange County, IN  right_only    1
#  La Salle County, IL  right_only    1
#  La Porte County, IN  right_only    1
#  Kentucky, KY         right_only    1
#  Kansas, KS           right_only    1
#  Kalawao County, HI   right_only    1
#  Iowa, IA             right_only    1
#  Indiana, IN          right_only    1
#  Illinois, IL         right_only    1
#  Idaho, ID            right_only    1
#  Hawaii, HI           right_only    1
#  Georgia, GA          right_only    1
#  Florida, FL          right_only    1
#  Delaware, DE         right_only    1
#  DeBaca County, NM    right_only    1
#  De Kalb County, IN   right_only    1
#  Connecticut, CT      right_only    1
#  Colorado, CO         right_only    1
#  California, CA       right_only    1
#  Arkansas, AR         right_only    1
#  Arizona, AZ          right_only    1
#  Mc Kean County, PA   right_only    1
#  Michigan, MI         right_only    1
#  Minnesota, MN        right_only    1
#  Oregon, OR           right_only    1
#  West Virginia, WV    right_only    1
#  Washington, WA       right_only    1
#  Virginia, VA         right_only    1
#  Vermont, VT          right_only    1
#  Utah, UT             right_only    1
#  Texas, TX            right_only    1
#  Tennessee, TN        right_only    1
#  South Dakota, SD     right_only    1
#  South Carolina, SC   right_only    1
#  Rhode Island, RI     right_only    1
#  Pennsylvania, PA     right_only    1
#  Oklahoma, OK         right_only    1
#  Mississippi, MS      right_only    1
#  Ohio, OH             right_only    1
#  North Dakota, ND     right_only    1
#  North Carolina, NC   right_only    1
#  New York, NY         right_only    1
#  New Mexico, NM       right_only    1
#  New Jersey, NJ       right_only    1
#  New Hampshire, NH    right_only    1
#  Nevada, NV           right_only    1
#  Nebraska, NE         right_only    1
#  Montana, MT          right_only    1
#  Missouri, MO         right_only    1
#  Alabama, AL          right_only    1
#  dtype: int64,
#  County_with_State    _merge
#  McKean County, PA    left_only    1
#  LaSalle County, IL   left_only    1
#  LaPorte County, IN   left_only    1
#  LaGrange County, IN  left_only    1
#  DeKalb County, IN    left_only    1
#  De Baca County, NM   left_only    1
#  dtype: int64)

# %%
state_names = ["Alaska", "Alabama", "Arkansas", "American Samoa", "Arizona", "California", "Colorado", "Connecticut", "Delaware", "Florida", "Georgia", "Guam", "Hawaii", "Iowa", "Idaho", "Illinois", "Indiana", "Kansas", "Kentucky", "Louisiana", "Massachusetts", "Maryland", "Maine", "Michigan", "Minnesota", "Missouri", "Mississippi", "Montana", "North Carolina", "North Dakota", "Nebraska", "New Hampshire", "New Jersey", "New Mexico", "Nevada", "New York", "Ohio", "Oklahoma", "Oregon", "Pennsylvania", "Puerto Rico", "Rhode Island", "South Carolina", "South Dakota", "Tennessee", "Texas", "Utah", "Virginia", "Virgin Islands", "Vermont", "Washington", "Wisconsin", "West Virginia", "Wyoming"]
poverty.drop(poverty.index[poverty["Area_name"].isin(state_names)], inplace=True)
poverty
# Out:
# /Users/shelleywang/anaconda3/envs/learn-env/lib/python3.8/site-packages/pandas/core/frame.py:4163: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(
# 3    FIPS_Code Stabr          Area_name Rural-urban_Continuum_Code_2003  \
# 6        01001    AL     Autauga County                               2
# 7        01003    AL     Baldwin County                               4
# 8        01005    AL     Barbour County                               6
# 9        01007    AL        Bibb County                               1
# 10       01009    AL      Blount County                               1
# ...        ...   ...                ...                             ...
# 3194     56037    WY  Sweetwater County                               5
# 3195     56039    WY       Teton County                               7
# 3196     56041    WY       Uinta County                               7
# 3197     56043    WY    Washakie County                               7
# 3198     56045    WY      Weston County                               7
#
# 3    Urban_Influence_Code_2003 Rural-urban_Continuum_Code_2013  \
# 6                            2                               2
# 7                            5                               3
# 8                            6                               6
# 9                            1                               1
# 10                           1                               1
# ...                        ...                             ...
# 3194                         8                               5
# 3195                         8                               7
# 3196                         8                               7
# 3197                        11                               7
# 3198                         9                               7
#
# 3    Urban_Influence_Code_ 2013 POVALL_2021 CI90LBALL_2021 CI90UBALL_2021  \
# 6                             2        6296           4772           7820
# 7                             2       25526          21599          29453
# 8                             6        5089           3773           6405
# 9                             1        4204           3324           5084
# 10                            1        6992           5516           8468
# ...                         ...         ...            ...            ...
# 3194                          8        3761           3048           4474
# 3195                          8        1392           1070           1714
# 3196                          8        1917           1457           2377
# 3197                         11         773            579            967
# 3198                          9         666            504            828
#
# 3     ... MEDHHINC_2021 CI90LBINC_2021 CI90UBINC_2021 POV04_2021  \
# 6     ...         66444          60061          72827        NaN
# 7     ...         65658          60723          70593        NaN
# 8     ...         38649          34308          42990        NaN
# 9     ...         48454          42438          54470        NaN
# 10    ...         56894          52632          61156        NaN
# ...   ...           ...            ...            ...        ...
# 3194  ...         74677          66928          82426        NaN
# 3195  ...        102709          90132         115286        NaN
# 3196  ...         70162          62206          78118        NaN
# 3197  ...         62176          55415          68937        NaN
# 3198  ...         62509          55613          69405        NaN
#
# 3    CI90LB04_2021 CI90UB04_2021 PCTPOV04_2021 CI90LB04P_2021 CI90UB04P_2021  \
# 6              NaN           NaN           NaN            NaN            NaN
# 7              NaN           NaN           NaN            NaN            NaN
# 8              NaN           NaN           NaN            NaN            NaN
# 9              NaN           NaN           NaN            NaN            NaN
# 10             NaN           NaN           NaN            NaN            NaN
# ...            ...           ...           ...            ...            ...
# 3194           NaN           NaN           NaN            NaN            NaN
# 3195           NaN           NaN           NaN            NaN            NaN
# 3196           NaN           NaN           NaN            NaN            NaN
# 3197           NaN           NaN           NaN            NaN            NaN
# 3198           NaN           NaN           NaN            NaN            NaN
#
# 3         County_with_State
# 6        Autauga County, AL
# 7        Baldwin County, AL
# 8        Barbour County, AL
# 9           Bibb County, AL
# 10        Blount County, AL
# ...                     ...
# 3194  Sweetwater County, WY
# 3195       Teton County, WY
# 3196       Uinta County, WY
# 3197    Washakie County, WY
# 3198      Weston County, WY
#
# [3114 rows x 35 columns]

# %%
"""
From poverty dataset, include:
* PCTPOVALL_2021, the overall percentage of people in poverty in 2021
* MEDHHINC_2021, the "[e]stimate of median household income 2021"
* County_with_State
"""

poverty = poverty[["PCTPOVALL_2021", "MEDHHINC_2021", "County_with_State"]]
poverty
# Out:
# 3    PCTPOVALL_2021 MEDHHINC_2021      County_with_State
# 6              10.7         66444     Autauga County, AL
# 7              10.8         65658     Baldwin County, AL
# 8                23         38649     Barbour County, AL
# 9              20.6         48454        Bibb County, AL
# 10               12         56894      Blount County, AL
# ...             ...           ...                    ...
# 3194            9.2         74677  Sweetwater County, WY
# 3195            5.9        102709       Teton County, WY
# 3196            9.4         70162       Uinta County, WY
# 3197           10.2         62176    Washakie County, WY
# 3198           10.4         62509      Weston County, WY
#
# [3114 rows x 3 columns]

# %%
check_overlap(df, poverty, "County_with_State")
# Out:
# (County_with_State    _merge
#  Mc Kean County, PA   right_only    1
#  Lagrange County, IN  right_only    1
#  La Salle County, IL  right_only    1
#  La Porte County, IN  right_only    1
#  Kalawao County, HI   right_only    1
#  DeBaca County, NM    right_only    1
#  De Kalb County, IN   right_only    1
#  dtype: int64,
#  County_with_State    _merge
#  McKean County, PA    left_only    1
#  LaSalle County, IL   left_only    1
#  LaPorte County, IN   left_only    1
#  LaGrange County, IN  left_only    1
#  DeKalb County, IN    left_only    1
#  De Baca County, NM   left_only    1
#  dtype: int64)

# %%
poverty["County_with_State"] = poverty["County_with_State"].replace("De Kalb County, IN", "DeKalb County, IN")
poverty["County_with_State"] = poverty["County_with_State"].replace("DeBaca County, NM", "De Baca County, NM")
poverty["County_with_State"] = poverty["County_with_State"].replace("La Porte County, IN", "LaPorte County, IN")
poverty["County_with_State"] = poverty["County_with_State"].replace("La Salle County, IL", "LaSalle County, IL")
poverty["County_with_State"] = poverty["County_with_State"].replace("Lagrange County, IN", "LaGrange County, IN")
poverty["County_with_State"] = poverty["County_with_State"].replace("Mc Kean County, PA", "McKean County, PA")

check_overlap(df, poverty, "County_with_State")
# Out:
# <ipython-input-870-ce0be59dcc0b>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   poverty["County_with_State"] = poverty["County_with_State"].replace("De Kalb County, IN", "DeKalb County, IN")
# <ipython-input-870-ce0be59dcc0b>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   poverty["County_with_State"] = poverty["County_with_State"].replace("DeBaca County, NM", "De Baca County, NM")
# <ipython-input-870-ce0be59dcc0b>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   poverty["County_with_State"] = poverty["County_with_State"].replace("La Porte County, IN", "LaPorte County, IN")
# <ipython-input-870-ce0be59dcc0b>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   poverty["County_with_State"] = poverty["County_with_State"].replace("La Salle County, IL", "LaSalle County, IL")
# <ipython-input-870-ce0be59dcc0b>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   poverty["County_with_State"] = poverty["County_with_State"].replace("Lagrange County, IN", "LaGrange County, IN")
# <ipython-input-870-ce0be59dcc0b>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   poverty["County_with_State"] = poverty["County_with_State"].replace("Mc Kean County, PA", "McKean County, PA")
# (County_with_State   _merge
#  Kalawao County, HI  right_only    1
#  dtype: int64,
#  Series([], dtype: int64))

# %%
poverty["County_with_State"].value_counts()
# Out:
# District of Columbia, DC    2
# Chase County, NE            1
# Iredell County, NC          1
# Gloucester County, NJ       1
# Scott County, MN            1
#                            ..
# Mississippi County, MO      1
# Elliott County, KY          1
# Pawnee County, NE           1
# Holmes County, MS           1
# Ross County, OH             1
# Name: County_with_State, Length: 3113, dtype: int64

# %%
poverty.drop_duplicates(subset="County_with_State", inplace=True)
poverty
# Out:
# <ipython-input-872-85d8b882428c>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   poverty.drop_duplicates(subset="County_with_State", inplace=True)
# 3    PCTPOVALL_2021 MEDHHINC_2021      County_with_State
# 6              10.7         66444     Autauga County, AL
# 7              10.8         65658     Baldwin County, AL
# 8                23         38649     Barbour County, AL
# 9              20.6         48454        Bibb County, AL
# 10               12         56894      Blount County, AL
# ...             ...           ...                    ...
# 3194            9.2         74677  Sweetwater County, WY
# 3195            5.9        102709       Teton County, WY
# 3196            9.4         70162       Uinta County, WY
# 3197           10.2         62176    Washakie County, WY
# 3198           10.4         62509      Weston County, WY
#
# [3113 rows x 3 columns]

# %%
poverty["County_with_State"].value_counts()
# Out:
# Chase County, NE          1
# Monroe County, IL         1
# Walker County, TX         1
# Gloucester County, NJ     1
# Scott County, MN          1
#                          ..
# Mississippi County, MO    1
# Elliott County, KY        1
# Pawnee County, NE         1
# Holmes County, MS         1
# Ross County, OH           1
# Name: County_with_State, Length: 3113, dtype: int64

# %%
df = pd.merge(df, poverty, how="inner", on="County_with_State")

# %%
df
# Out:
#       per_gop  per_dem  per_third_party      County_with_State        Date  \
# 0        71.4     27.0              1.5     Autauga County, AL  05/10/2023
# 1        76.2     22.4              1.4     Baldwin County, AL  05/10/2023
# 2        53.5     45.8              0.8     Barbour County, AL  05/10/2023
# 3        78.4     20.7              0.9        Bibb County, AL  05/10/2023
# 4        89.6      9.6              0.9      Blount County, AL  05/10/2023
# ...       ...      ...              ...                    ...         ...
# 3107     73.7     23.0              3.3  Sweetwater County, WY  05/10/2023
# 3108     29.6     67.1              3.3       Teton County, WY  05/10/2023
# 3109     79.7     16.9              3.4       Uinta County, WY  05/10/2023
# 3110     80.9     16.2              2.9    Washakie County, WY  05/10/2023
# 3111     87.7     10.2              2.1      Weston County, WY  05/10/2023
#
#       Completeness_pct Metro_status SVI_CTGY  Census2019 PCTPOVALL_2021  \
# 0                 92.6        Metro        C     55869.0           10.7
# 1                 92.6        Metro        B    223234.0           10.8
# 2                 92.6    Non-metro        D     24686.0             23
# 3                 92.6        Metro        D     22394.0           20.6
# 4                 92.6        Metro        C     57826.0             12
# ...                ...          ...      ...         ...            ...
# 3107              97.1    Non-metro        B     42343.0            9.2
# 3108              97.1    Non-metro        A     23464.0            5.9
# 3109              97.1    Non-metro        B     20226.0            9.4
# 3110              97.1    Non-metro        B      7805.0           10.2
# 3111              97.1    Non-metro        A      6927.0           10.4
#
#      MEDHHINC_2021
# 0            66444
# 1            65658
# 2            38649
# 3            48454
# 4            56894
# ...            ...
# 3107         74677
# 3108        102709
# 3109         70162
# 3110         62176
# 3111         62509
#
# [3112 rows x 11 columns]

# %%
df[df["County_with_State"].str.endswith("CT")]["County_with_State"].value_counts()
# Out:
# Litchfield County, CT    1
# Fairfield County, CT     1
# Tolland County, CT       1
# Windham County, CT       1
# New Haven County, CT     1
# Middlesex County, CT     1
# New London County, CT    1
# Hartford County, CT      1
# Name: County_with_State, dtype: int64

# %% [markdown]
# # Deaths!

# %%
deaths = pd.read_csv('../data/Provisional_COVID-19_Deaths_by_County__and_Race_and_Hispanic_Origin_20240102.csv')
deaths
# Out:
#       Data as of  Start Date    End Date State                   County Name  \
# 0     09/27/2023  01/01/2020  09/23/2023    AK        Anchorage Municipality
# 1     09/27/2023  01/01/2020  09/23/2023    AK        Anchorage Municipality
# 2     09/27/2023  01/01/2020  09/23/2023    AK        Anchorage Municipality
# 3     09/27/2023  01/01/2020  09/23/2023    AK  Fairbanks North Star Borough
# 4     09/27/2023  01/01/2020  09/23/2023    AK  Fairbanks North Star Borough
# ...          ...         ...         ...   ...                           ...
# 3682  09/27/2023  01/01/2020  09/23/2023    WY               Sheridan County
# 3683  09/27/2023  01/01/2020  09/23/2023    WY               Sheridan County
# 3684  09/27/2023  01/01/2020  09/23/2023    WY             Sweetwater County
# 3685  09/27/2023  01/01/2020  09/23/2023    WY             Sweetwater County
# 3686  09/27/2023  01/01/2020  09/23/2023    WY             Sweetwater County
#
#       Urban Rural Code  FIPS State  FIPS County  FIPS Code  \
# 0                    3           2           20       2020
# 1                    3           2           20       2020
# 2                    3           2           20       2020
# 3                    4           2           90       2090
# 4                    4           2           90       2090
# ...                ...         ...          ...        ...
# 3682                 5          56           33      56033
# 3683                 5          56           33      56033
# 3684                 5          56           37      56037
# 3685                 5          56           37      56037
# 3686                 5          56           37      56037
#
#                                  Indicator  ...  COVID-19 Deaths  \
# 0     Distribution of all-cause deaths (%)  ...              787
# 1      Distribution of COVID-19 deaths (%)  ...              787
# 2           Distribution of population (%)  ...              787
# 3     Distribution of all-cause deaths (%)  ...              214
# 4      Distribution of COVID-19 deaths (%)  ...              214
# ...                                    ...  ...              ...
# 3682   Distribution of COVID-19 deaths (%)  ...              101
# 3683        Distribution of population (%)  ...              101
# 3684  Distribution of all-cause deaths (%)  ...              115
# 3685   Distribution of COVID-19 deaths (%)  ...              115
# 3686        Distribution of population (%)  ...              115
#
#       Non-Hispanic White  Non-Hispanic Black  \
# 0                  0.568               0.044
# 1                  0.452               0.037
# 2                  0.564               0.052
# 3                  0.710               0.024
# 4                  0.626                 NaN
# ...                  ...                 ...
# 3682               0.861                 NaN
# 3683               0.913               0.007
# 3684               0.885               0.013
# 3685               0.887                 NaN
# 3686               0.792               0.011
#
#       Non-Hispanic American Indian or Alaska Native  Non-Hispanic Asian  \
# 0                                             0.216               0.058
# 1                                             0.255               0.111
# 2                                             0.083               0.098
# 3                                             0.173               0.020
# 4                                             0.257                 NaN
# ...                                             ...                 ...
# 3682                                            NaN                 NaN
# 3683                                          0.011               0.008
# 3684                                          0.009                 NaN
# 3685                                            NaN                 NaN
# 3686                                          0.008               0.009
#
#       Non-Hispanic Native Hawaiian or Other Pacific Islander  Hispanic  Other  \
# 0                                                 0.030          0.033  0.050
# 1                                                 0.074          0.038  0.033
# 2                                                 0.031          0.095  0.077
# 3                                                   NaN          0.027  0.044
# 4                                                   NaN            NaN  0.056
# ...                                                 ...            ...    ...
# 3682                                                NaN            NaN    NaN
# 3683                                              0.001          0.047  0.014
# 3684                                                NaN          0.083    NaN
# 3685                                                NaN          0.096    NaN
# 3686                                              0.001          0.162  0.017
#
#       Urban Rural Description  \
# 0                Medium metro
# 1                Medium metro
# 2                Medium metro
# 3                 Small metro
# 4                 Small metro
# ...                       ...
# 3682             Micropolitan
# 3683             Micropolitan
# 3684             Micropolitan
# 3685             Micropolitan
# 3686             Micropolitan
#
#                                                Footnote
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3     One or more data cells have counts between 1-9...
# 4     One or more data cells have counts between 1-9...
# ...                                                 ...
# 3682  One or more data cells have counts between 1-9...
# 3683                                                NaN
# 3684  One or more data cells have counts between 1-9...
# 3685  One or more data cells have counts between 1-9...
# 3686                                                NaN
#
# [3687 rows x 21 columns]

# %%
3687/3
# Out:
# 1229.0

# %%
deaths["County Name"].value_counts()
# Out:
# Jefferson County      42
# Washington County     39
# Montgomery County     30
# Jackson County        30
# Franklin County       27
#                       ..
# Frederick County       3
# Citrus County          3
# St. Charles County     3
# Alexandria city        3
# Sauk County            3
# Name: County Name, Length: 901, dtype: int64

# %%
deaths["Indicator"].value_counts()
# Out:
# Distribution of all-cause deaths (%)    1229
# Distribution of COVID-19 deaths (%)     1229
# Distribution of population (%)          1229
# Name: Indicator, dtype: int64

# %%
County_with_State(deaths, "County Name", "State")
deaths.head()
# Out:
#    Data as of  Start Date    End Date State                   County Name  \
# 0  09/27/2023  01/01/2020  09/23/2023    AK        Anchorage Municipality
# 1  09/27/2023  01/01/2020  09/23/2023    AK        Anchorage Municipality
# 2  09/27/2023  01/01/2020  09/23/2023    AK        Anchorage Municipality
# 3  09/27/2023  01/01/2020  09/23/2023    AK  Fairbanks North Star Borough
# 4  09/27/2023  01/01/2020  09/23/2023    AK  Fairbanks North Star Borough
#
#    Urban Rural Code  FIPS State  FIPS County  FIPS Code  \
# 0                 3           2           20       2020
# 1                 3           2           20       2020
# 2                 3           2           20       2020
# 3                 4           2           90       2090
# 4                 4           2           90       2090
#
#                               Indicator  ...  Non-Hispanic White  \
# 0  Distribution of all-cause deaths (%)  ...               0.568
# 1   Distribution of COVID-19 deaths (%)  ...               0.452
# 2        Distribution of population (%)  ...               0.564
# 3  Distribution of all-cause deaths (%)  ...               0.710
# 4   Distribution of COVID-19 deaths (%)  ...               0.626
#
#    Non-Hispanic Black  Non-Hispanic American Indian or Alaska Native  \
# 0               0.044                                          0.216
# 1               0.037                                          0.255
# 2               0.052                                          0.083
# 3               0.024                                          0.173
# 4                 NaN                                          0.257
#
#    Non-Hispanic Asian  Non-Hispanic Native Hawaiian or Other Pacific Islander  \
# 0               0.058                                              0.030
# 1               0.111                                              0.074
# 2               0.098                                              0.031
# 3               0.020                                                NaN
# 4                 NaN                                                NaN
#
#    Hispanic  Other  Urban Rural Description  \
# 0     0.033  0.050             Medium metro
# 1     0.038  0.033             Medium metro
# 2     0.095  0.077             Medium metro
# 3     0.027  0.044              Small metro
# 4       NaN  0.056              Small metro
#
#                                             Footnote  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3  One or more data cells have counts between 1-9...
# 4  One or more data cells have counts between 1-9...
#
#                   County_with_State
# 0        Anchorage Municipality, AK
# 1        Anchorage Municipality, AK
# 2        Anchorage Municipality, AK
# 3  Fairbanks North Star Borough, AK
# 4  Fairbanks North Star Borough, AK
#
# [5 rows x 22 columns]

# %%
deaths = deaths[deaths["Indicator"] == "Distribution of COVID-19 deaths (%)"]
deaths
# Out:
#       Data as of  Start Date    End Date State                   County Name  \
# 1     09/27/2023  01/01/2020  09/23/2023    AK        Anchorage Municipality
# 4     09/27/2023  01/01/2020  09/23/2023    AK  Fairbanks North Star Borough
# 7     09/27/2023  01/01/2020  09/23/2023    AK     Matanuska-Susitna Borough
# 10    09/27/2023  01/01/2020  09/23/2023    AL                Autauga County
# 13    09/27/2023  01/01/2020  09/23/2023    AL                Baldwin County
# ...          ...         ...         ...   ...                           ...
# 3673  09/27/2023  01/01/2020  09/23/2023    WY                Laramie County
# 3676  09/27/2023  01/01/2020  09/23/2023    WY                Natrona County
# 3679  09/27/2023  01/01/2020  09/23/2023    WY                   Park County
# 3682  09/27/2023  01/01/2020  09/23/2023    WY               Sheridan County
# 3685  09/27/2023  01/01/2020  09/23/2023    WY             Sweetwater County
#
#       Urban Rural Code  FIPS State  FIPS County  FIPS Code  \
# 1                    3           2           20       2020
# 4                    4           2           90       2090
# 7                    3           2          170       2170
# 10                   3           1            1       1001
# 13                   4           1            3       1003
# ...                ...         ...          ...        ...
# 3673                 4          56           21      56021
# 3676                 4          56           25      56025
# 3679                 6          56           29      56029
# 3682                 5          56           33      56033
# 3685                 5          56           37      56037
#
#                                 Indicator  ...  Non-Hispanic White  \
# 1     Distribution of COVID-19 deaths (%)  ...               0.452
# 4     Distribution of COVID-19 deaths (%)  ...               0.626
# 7     Distribution of COVID-19 deaths (%)  ...               0.826
# 10    Distribution of COVID-19 deaths (%)  ...               0.761
# 13    Distribution of COVID-19 deaths (%)  ...               0.884
# ...                                   ...  ...                 ...
# 3673  Distribution of COVID-19 deaths (%)  ...               0.776
# 3676  Distribution of COVID-19 deaths (%)  ...               0.824
# 3679  Distribution of COVID-19 deaths (%)  ...               0.926
# 3682  Distribution of COVID-19 deaths (%)  ...               0.861
# 3685  Distribution of COVID-19 deaths (%)  ...               0.887
#
#       Non-Hispanic Black  Non-Hispanic American Indian or Alaska Native  \
# 1                  0.037                                          0.255
# 4                    NaN                                          0.257
# 7                    NaN                                          0.083
# 10                 0.218                                            NaN
# 13                 0.086                                            NaN
# ...                  ...                                            ...
# 3673                 NaN                                            NaN
# 3676                 NaN                                          0.088
# 3679                 NaN                                            NaN
# 3682                 NaN                                            NaN
# 3685                 NaN                                            NaN
#
#       Non-Hispanic Asian  \
# 1                  0.111
# 4                    NaN
# 7                    NaN
# 10                   NaN
# 13                   NaN
# ...                  ...
# 3673                 NaN
# 3676                 NaN
# 3679                 NaN
# 3682                 NaN
# 3685                 NaN
#
#       Non-Hispanic Native Hawaiian or Other Pacific Islander  Hispanic  Other  \
# 1                                                 0.074          0.038  0.033
# 4                                                   NaN            NaN  0.056
# 7                                                   NaN          0.046    NaN
# 10                                                  NaN            NaN    NaN
# 13                                                  NaN          0.023    NaN
# ...                                                 ...            ...    ...
# 3673                                                NaN          0.170    NaN
# 3676                                                NaN          0.069    NaN
# 3679                                                NaN            NaN    NaN
# 3682                                                NaN            NaN    NaN
# 3685                                                NaN          0.096    NaN
#
#       Urban Rural Description  \
# 1                Medium metro
# 4                 Small metro
# 7                Medium metro
# 10               Medium metro
# 13                Small metro
# ...                       ...
# 3673              Small metro
# 3676              Small metro
# 3679                  Noncore
# 3682             Micropolitan
# 3685             Micropolitan
#
#                                                Footnote  \
# 1                                                   NaN
# 4     One or more data cells have counts between 1-9...
# 7     One or more data cells have counts between 1-9...
# 10    One or more data cells have counts between 1-9...
# 13    One or more data cells have counts between 1-9...
# ...                                                 ...
# 3673  One or more data cells have counts between 1-9...
# 3676  One or more data cells have counts between 1-9...
# 3679  One or more data cells have counts between 1-9...
# 3682  One or more data cells have counts between 1-9...
# 3685  One or more data cells have counts between 1-9...
#
#                      County_with_State
# 1           Anchorage Municipality, AK
# 4     Fairbanks North Star Borough, AK
# 7        Matanuska-Susitna Borough, AK
# 10                  Autauga County, AL
# 13                  Baldwin County, AL
# ...                                ...
# 3673                Laramie County, WY
# 3676                Natrona County, WY
# 3679                   Park County, WY
# 3682               Sheridan County, WY
# 3685             Sweetwater County, WY
#
# [1229 rows x 22 columns]

# %%
check_overlap(df, deaths, "County_with_State")
# Out:
# (County_with_State                 _merge
#  Matanuska-Susitna Borough, AK     right_only    1
#  La Salle County, IL               right_only    1
#  Fairbanks North Star Borough, AK  right_only    1
#  Anchorage Municipality, AK        right_only    1
#  dtype: int64,
#  County_with_State          _merge
#  Ziebach County, SD         left_only    1
#  Gosper County, NE          left_only    1
#  Gladwin County, MI         left_only    1
#  Glascock County, GA        left_only    1
#  Glasscock County, TX       left_only    1
#                                         ..
#  Northampton County, NC     left_only    1
#  Northampton County, VA     left_only    1
#  Northumberland County, VA  left_only    1
#  Norton County, KS          left_only    1
#  Abbeville County, SC       left_only    1
#  Length: 1887, dtype: int64)

# %% [markdown]
# # Census & race

# %%
census_race = pd.read_csv('../data/cc-est2022-all.csv', encoding="latin-1")
census_race["state_abbrev"] = census_race["STNAME"].map(state_abbrevs)
County_with_State(census_race, "CTYNAME", "state_abbrev")
census_race
# Out:
#         SUMLEV  STATE  COUNTY   STNAME         CTYNAME  YEAR  AGEGRP  TOT_POP  \
# 0           50      1       1  Alabama  Autauga County     1       0    58802
# 1           50      1       1  Alabama  Autauga County     1       1     3443
# 2           50      1       1  Alabama  Autauga County     1       2     3613
# 3           50      1       1  Alabama  Autauga County     1       3     4131
# 4           50      1       1  Alabama  Autauga County     1       4     3963
# ...        ...    ...     ...      ...             ...   ...     ...      ...
# 238939      50     56      45  Wyoming   Weston County     4      14      590
# 238940      50     56      45  Wyoming   Weston County     4      15      415
# 238941      50     56      45  Wyoming   Weston County     4      16      254
# 238942      50     56      45  Wyoming   Weston County     4      17      141
# 238943      50     56      45  Wyoming   Weston County     4      18      170
#
#         TOT_MALE  TOT_FEMALE  ...  HBAC_MALE  HBAC_FEMALE  HIAC_MALE  \
# 0          28761       30041  ...        112           97         40
# 1           1790        1653  ...         14            9          3
# 2           1849        1764  ...          5            8          7
# 3           2121        2010  ...         10           10          1
# 4           2003        1960  ...          8            9          5
# ...          ...         ...  ...        ...          ...        ...
# 238939       323         267  ...          0            1          0
# 238940       231         184  ...          0            0          0
# 238941       127         127  ...          0            0          0
# 238942        71          70  ...          0            0          1
# 238943        58         112  ...          0            0          0
#
#         HIAC_FEMALE  HAAC_MALE  HAAC_FEMALE  HNAC_MALE  HNAC_FEMALE  \
# 0                30         22           24         19           11
# 1                 1          9            1          3            1
# 2                 3          0            1          1            2
# 3                 3          2            2          2            1
# 4                 2          2            4          3            2
# ...             ...        ...          ...        ...          ...
# 238939            0          0            0          0            0
# 238940            0          0            0          0            0
# 238941            0          0            0          0            0
# 238942            0          0            0          0            0
# 238943            0          0            0          0            0
#
#         state_abbrev   County_with_State
# 0                 AL  Autauga County, AL
# 1                 AL  Autauga County, AL
# 2                 AL  Autauga County, AL
# 3                 AL  Autauga County, AL
# 4                 AL  Autauga County, AL
# ...              ...                 ...
# 238939            WY   Weston County, WY
# 238940            WY   Weston County, WY
# 238941            WY   Weston County, WY
# 238942            WY   Weston County, WY
# 238943            WY   Weston County, WY
#
# [238944 rows x 82 columns]

# %%
# Removing Alaska and other territories
census_race = drop_terrs(census_race, "state_abbrev")

# Also dropping CT because they changed from counties to different administrative districts
census_race = census_race[census_race["state_abbrev"] != "CT"]

# %% [markdown]
# Note: because CT stopped using counties in the census in 2022, we are going to use other data.
# [wiki link](https://en.wikipedia.org/wiki/List_of_counties_in_Connecticut)

# %%
# Including all age groups
census_race = census_race[census_race["AGEGRP"] == 0]
# Using year 2022
census_race = census_race[census_race["YEAR"] == 4]

# %%
census_race["County_with_State"].value_counts()
# Out:
# Chase County, NE          1
# Monroe County, IL         1
# Walker County, TX         1
# Gloucester County, NJ     1
# Scott County, MN          1
#                          ..
# Fauquier County, VA       1
# York County, NE           1
# Ringgold County, IA       1
# Mississippi County, MO    1
# Ross County, OH           1
# Name: County_with_State, Length: 3105, dtype: int64

# %%
census_race["WA"] = round(100 * (census_race["WA_MALE"] + census_race["WA_FEMALE"])/census_race["TOT_POP"], 1)
census_race["BA"] = round(100 * (census_race["BA_MALE"] + census_race["BA_FEMALE"])/census_race["TOT_POP"], 1)
census_race["IA"] = round(100 * (census_race["IA_MALE"] + census_race["IA_FEMALE"])/census_race["TOT_POP"], 1)
census_race["AAPI"] = round(100 * (census_race["AA_MALE"] + census_race["NA_MALE"] +  census_race["AA_FEMALE"] + census_race["NA_FEMALE"])/census_race["TOT_POP"], 1)
census_race.head()
# Out:
#      SUMLEV  STATE  COUNTY   STNAME         CTYNAME  YEAR  AGEGRP  TOT_POP  \
# 57       50      1       1  Alabama  Autauga County     4       0    59759
# 133      50      1       3  Alabama  Baldwin County     4       0   246435
# 209      50      1       5  Alabama  Barbour County     4       0    24706
# 285      50      1       7  Alabama     Bibb County     4       0    22005
# 361      50      1       9  Alabama   Blount County     4       0    59512
#
#      TOT_MALE  TOT_FEMALE  ...  HAAC_MALE  HAAC_FEMALE  HNAC_MALE  \
# 57      29105       30654  ...         23           22         22
# 133    120164      126271  ...        118          132         88
# 209     13064       11642  ...         10            9         33
# 285     11775       10230  ...          8           10         19
# 361     29583       29929  ...         15           29         37
#
#      HNAC_FEMALE  state_abbrev   County_with_State    WA    BA   IA  AAPI
# 57            19            AL  Autauga County, AL  74.8  21.4  0.5   1.3
# 133           86            AL  Baldwin County, AL  87.4   8.4  0.8   1.2
# 209           18            AL  Barbour County, AL  49.2  47.7  0.7   0.7
# 285            6            AL     Bibb County, AL  76.5  21.0  0.6   0.4
# 361           28            AL   Blount County, AL  95.4   1.9  0.6   0.6
#
# [5 rows x 86 columns]

# %%
# link: https://portal.ct.gov/DPH/Health-Information-Systems--Reporting/Population/Annual-State-County-Population-with-Demographics-for-2000-2019
# https://docs.google.com/spreadsheets/d/1ah9hCG5YFZtguc8Xabcix1ppcR4MWhNh2fq3cyWJ18I/edit?usp=sharing
# dw about this lol
census_race = census_race[["WA", "BA", "IA", "AAPI", "County_with_State"]]
census_race.loc[238869] = [749569, 129086, 5810, 58867, "Fairfield County, CT"]
census_race.loc[238870] = [679325, 149165, 6027, 57203, "Hartford County, CT"]
census_race.loc[238871] = [170038, 5106, 775, 4414, "Litchfield County, CT"]
census_race.loc[238872] = [145937, 10011, 567, 5921, "Middlesex County, CT"]
census_race.loc[238873] = [670878, 138658, 5643, 39578, "New Haven County, CT"]
census_race.loc[238874] = [226391, 22194, 3820, 12801, "New London County, CT"]
census_race.loc[238875] = [135244, 6686, 511, 8280, "Tolland County, CT"]
census_race.loc[238876] = [109022, 4533, 1108, 2119, "Windham County, CT"]
census_race.tail(10)
# Out:
#               WA        BA      IA     AAPI      County_with_State
# 238849      94.4       0.5     1.7      1.0    Washakie County, WY
# 238925      92.8       0.8     2.1      1.5      Weston County, WY
# 238869  749569.0  129086.0  5810.0  58867.0   Fairfield County, CT
# 238870  679325.0  149165.0  6027.0  57203.0    Hartford County, CT
# 238871  170038.0    5106.0   775.0   4414.0  Litchfield County, CT
# 238872  145937.0   10011.0   567.0   5921.0   Middlesex County, CT
# 238873  670878.0  138658.0  5643.0  39578.0   New Haven County, CT
# 238874  226391.0   22194.0  3820.0  12801.0  New London County, CT
# 238875  135244.0    6686.0   511.0   8280.0     Tolland County, CT
# 238876  109022.0    4533.0  1108.0   2119.0     Windham County, CT

# %%
check_overlap(df, census_race, "County_with_State")
# Out:
# (County_with_State    _merge
#  LaSalle Parish, LA   right_only    1
#  Kalawao County, HI   right_only    1
#  Doña Ana County, NM  right_only    1
#  dtype: int64,
#  County_with_State    _merge
#  La Salle Parish, LA  left_only    1
#  Dona Ana County, NM  left_only    1
#  dtype: int64)

# %%
census_race["County_with_State"] = census_race["County_with_State"].replace("Doña Ana County, NM", "Dona Ana County, NM")
census_race["County_with_State"] = census_race["County_with_State"].replace("LaSalle Parish, LA", "La Salle Parish, LA")

df = pd.merge(df, census_race, how="inner", on="County_with_State")
df
# Out:
#       per_gop  per_dem  per_third_party      County_with_State        Date  \
# 0        71.4     27.0              1.5     Autauga County, AL  05/10/2023
# 1        76.2     22.4              1.4     Baldwin County, AL  05/10/2023
# 2        53.5     45.8              0.8     Barbour County, AL  05/10/2023
# 3        78.4     20.7              0.9        Bibb County, AL  05/10/2023
# 4        89.6      9.6              0.9      Blount County, AL  05/10/2023
# ...       ...      ...              ...                    ...         ...
# 3107     73.7     23.0              3.3  Sweetwater County, WY  05/10/2023
# 3108     29.6     67.1              3.3       Teton County, WY  05/10/2023
# 3109     79.7     16.9              3.4       Uinta County, WY  05/10/2023
# 3110     80.9     16.2              2.9    Washakie County, WY  05/10/2023
# 3111     87.7     10.2              2.1      Weston County, WY  05/10/2023
#
#       Completeness_pct Metro_status SVI_CTGY  Census2019 PCTPOVALL_2021  \
# 0                 92.6        Metro        C     55869.0           10.7
# 1                 92.6        Metro        B    223234.0           10.8
# 2                 92.6    Non-metro        D     24686.0             23
# 3                 92.6        Metro        D     22394.0           20.6
# 4                 92.6        Metro        C     57826.0             12
# ...                ...          ...      ...         ...            ...
# 3107              97.1    Non-metro        B     42343.0            9.2
# 3108              97.1    Non-metro        A     23464.0            5.9
# 3109              97.1    Non-metro        B     20226.0            9.4
# 3110              97.1    Non-metro        B      7805.0           10.2
# 3111              97.1    Non-metro        A      6927.0           10.4
#
#      MEDHHINC_2021    WA    BA   IA  AAPI
# 0            66444  74.8  21.4  0.5   1.3
# 1            65658  87.4   8.4  0.8   1.2
# 2            38649  49.2  47.7  0.7   0.7
# 3            48454  76.5  21.0  0.6   0.4
# 4            56894  95.4   1.9  0.6   0.6
# ...            ...   ...   ...  ...   ...
# 3107         74677  93.9   1.3  1.5   1.1
# 3108        102709  94.2   0.8  1.1   2.0
# 3109         70162  95.3   0.7  1.5   0.8
# 3110         62176  94.4   0.5  1.7   1.0
# 3111         62509  92.8   0.8  2.1   1.5
#
# [3112 rows x 15 columns]

# %% [markdown]
# # Census & age
#
# CT median age: 40.9 [census link](https://data.census.gov/profile/Connecticut?g=040XX00US09)

# %%
census_age = pd.read_csv('../data/cc-est2022-agesex-all.csv')
census_age["state_abbrev"] = census_age["STNAME"].map(state_abbrevs)
County_with_State(census_age, "CTYNAME", "state_abbrev")
census_age = drop_terrs(census_age, "state_abbrev")
census_age = census_age[census_age["state_abbrev"] != "CT"]
census_age = census_age[census_age["YEAR"] == 4]
census_age = census_age[["MEDIAN_AGE_TOT", "County_with_State"]]
census_age
# Out:
#        MEDIAN_AGE_TOT      County_with_State
# 3                39.2     Autauga County, AL
# 7                44.1     Baldwin County, AL
# 11               41.5     Barbour County, AL
# 15               40.9        Bibb County, AL
# 19               41.2      Blount County, AL
# ...               ...                    ...
# 12559            37.7  Sweetwater County, WY
# 12563            41.0       Teton County, WY
# 12567            38.0       Uinta County, WY
# 12571            44.8    Washakie County, WY
# 12575            44.5      Weston County, WY
#
# [3105 rows x 2 columns]

# %%
# Imputing median CT age per county -- https://data.census.gov/profile/Connecticut?g=040XX00US09
census_age.loc[12576] = [40.9, "Fairfield County, CT"]
census_age.loc[12577] = [40.9, "Hartford County, CT"]
census_age.loc[12578] = [40.9, "Litchfield County, CT"]
census_age.loc[12579] = [40.9, "Middlesex County, CT"]
census_age.loc[12580] = [40.9, "New Haven County, CT"]
census_age.loc[12581] = [40.9, "New London County, CT"]
census_age.loc[12582] = [40.9, "Tolland County, CT"]
census_age.loc[12583] = [40.9, "Windham County, CT"]

census_age.tail(10)
# Out:
#        MEDIAN_AGE_TOT      County_with_State
# 12571            44.8    Washakie County, WY
# 12575            44.5      Weston County, WY
# 12576            40.9   Fairfield County, CT
# 12577            40.9    Hartford County, CT
# 12578            40.9  Litchfield County, CT
# 12579            40.9   Middlesex County, CT
# 12580            40.9   New Haven County, CT
# 12581            40.9  New London County, CT
# 12582            40.9     Tolland County, CT
# 12583            40.9     Windham County, CT

# %%
census_age.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3113 entries, 3 to 12583
# Data columns (total 2 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   MEDIAN_AGE_TOT     3113 non-null   float64
#  1   County_with_State  3113 non-null   object
# dtypes: float64(1), object(1)
# memory usage: 73.0+ KB

# %%
check_overlap(df, census_age, "County_with_State")
# Out:
# (County_with_State    _merge
#  LaSalle Parish, LA   right_only    1
#  Kalawao County, HI   right_only    1
#  Doña Ana County, NM  right_only    1
#  dtype: int64,
#  County_with_State    _merge
#  La Salle Parish, LA  left_only    1
#  Dona Ana County, NM  left_only    1
#  dtype: int64)

# %%
census_age["County_with_State"] = census_age["County_with_State"].replace("Doña Ana County, NM", "Dona Ana County, NM")
census_age["County_with_State"] = census_age["County_with_State"].replace("LaSalle Parish, LA", "La Salle Parish, LA")

# %%
df = pd.merge(df, census_age, how="inner", on="County_with_State")
df
# Out:
#       per_gop  per_dem  per_third_party      County_with_State        Date  \
# 0        71.4     27.0              1.5     Autauga County, AL  05/10/2023
# 1        76.2     22.4              1.4     Baldwin County, AL  05/10/2023
# 2        53.5     45.8              0.8     Barbour County, AL  05/10/2023
# 3        78.4     20.7              0.9        Bibb County, AL  05/10/2023
# 4        89.6      9.6              0.9      Blount County, AL  05/10/2023
# ...       ...      ...              ...                    ...         ...
# 3107     73.7     23.0              3.3  Sweetwater County, WY  05/10/2023
# 3108     29.6     67.1              3.3       Teton County, WY  05/10/2023
# 3109     79.7     16.9              3.4       Uinta County, WY  05/10/2023
# 3110     80.9     16.2              2.9    Washakie County, WY  05/10/2023
# 3111     87.7     10.2              2.1      Weston County, WY  05/10/2023
#
#       Completeness_pct Metro_status SVI_CTGY  Census2019 PCTPOVALL_2021  \
# 0                 92.6        Metro        C     55869.0           10.7
# 1                 92.6        Metro        B    223234.0           10.8
# 2                 92.6    Non-metro        D     24686.0             23
# 3                 92.6        Metro        D     22394.0           20.6
# 4                 92.6        Metro        C     57826.0             12
# ...                ...          ...      ...         ...            ...
# 3107              97.1    Non-metro        B     42343.0            9.2
# 3108              97.1    Non-metro        A     23464.0            5.9
# 3109              97.1    Non-metro        B     20226.0            9.4
# 3110              97.1    Non-metro        B      7805.0           10.2
# 3111              97.1    Non-metro        A      6927.0           10.4
#
#      MEDHHINC_2021    WA    BA   IA  AAPI  MEDIAN_AGE_TOT
# 0            66444  74.8  21.4  0.5   1.3            39.2
# 1            65658  87.4   8.4  0.8   1.2            44.1
# 2            38649  49.2  47.7  0.7   0.7            41.5
# 3            48454  76.5  21.0  0.6   0.4            40.9
# 4            56894  95.4   1.9  0.6   0.6            41.2
# ...            ...   ...   ...  ...   ...             ...
# 3107         74677  93.9   1.3  1.5   1.1            37.7
# 3108        102709  94.2   0.8  1.1   2.0            41.0
# 3109         70162  95.3   0.7  1.5   0.8            38.0
# 3110         62176  94.4   0.5  1.7   1.0            44.8
# 3111         62509  92.8   0.8  2.1   1.5            44.5
#
# [3112 rows x 16 columns]

# %% [markdown]
# # Education

# %%
education = pd.read_excel('../data/Education.xlsx')
education.columns = education.iloc[2]
education.drop(education.index[0:4], inplace=True)
education.head()
# Out:
# 2 Federal Information Processing Standard (FIPS) Code State       Area name  \
# 4                                              01000     AL         Alabama
# 5                                              01001     AL  Autauga County
# 6                                              01003     AL  Baldwin County
# 7                                              01005     AL  Barbour County
# 8                                              01007     AL     Bibb County
#
# 2 2003 Rural-urban Continuum Code 2003 Urban Influence Code  \
# 4                             NaN                       NaN
# 5                               2                         2
# 6                               4                         5
# 7                               6                         6
# 8                               1                         1
#
# 2 2013 Rural-urban Continuum Code 2013 Urban Influence Code  \
# 4                             NaN                       NaN
# 5                               2                         2
# 6                               3                         2
# 7                               6                         6
# 8                               1                         1
#
# 2 Less than a high school diploma, 1970 High school diploma only, 1970  \
# 4                               1062306                         468269
# 5                                  6611                           3757
# 6                                 18726                           8426
# 7                                  8120                           2242
# 8                                  5272                           1402
#
# 2 Some college (1-3 years), 1970  ...  \
# 4                         136287  ...
# 5                            933  ...
# 6                           2334  ...
# 7                            581  ...
# 8                            238  ...
#
# 2 Percent of adults completing some college or associate's degree, 2008-12  \
# 4                                            29.0229
# 5                                            29.6181
# 6                                            31.8195
# 7                                            25.7718
# 8                                            25.5381
#
# 2 Percent of adults with a bachelor's degree or higher, 2008-12  \
# 4                                            22.2649
# 5                                            21.7078
# 6                                            27.7416
# 7                                            14.5243
# 8                                              8.996
#
# 2 Less than a high school diploma, 2017-21 High school diploma only, 2017-21  \
# 4                                   430047                           1041209
# 5                                     4126                             12977
# 6                                    14555                             44342
# 7                                     4378                              6600
# 8                                     3125                              7052
#
# 2 Some college or associate's degree, 2017-21  \
# 4                                     1032122
# 5                                       11367
# 6                                       50518
# 7                                        5010
# 8                                        3967
#
# 2 Bachelor's degree or higher, 2017-21  \
# 4                               910425
# 5                                11144
# 6                                52562
# 7                                 2007
# 8                                 1913
#
# 2 Percent of adults with less than a high school diploma, 2017-21  \
# 4                                            12.5973
# 5                                            10.4155
# 6                                            8.98584
# 7                                             24.329
# 8                                            19.4619
#
# 2 Percent of adults with a high school diploma only, 2017-21  \
# 4                                               30.5
# 5                                            32.7586
# 6                                            27.3755
# 7                                            36.6769
# 8                                            43.9185
#
# 2 Percent of adults completing some college or associate's degree, 2017-21  \
# 4                                            30.2338
# 5                                            28.6944
# 6                                            31.1884
# 7                                            27.8411
# 8                                            24.7057
#
# 2 Percent of adults with a bachelor's degree or higher, 2017-21
# 4                                            26.6689
# 5                                            28.1315
# 6                                            32.4503
# 7                                            11.1531
# 8                                            11.9138
#
# [5 rows x 55 columns]

# %%
education.drop(education.index[education["Area name"].isin(state_names)], inplace=True)
education = drop_terrs(education, "State")
County_with_State(education, "Area name", "State")
education.head()
# Out:
# 2 Federal Information Processing Standard (FIPS) Code State       Area name  \
# 5                                              01001     AL  Autauga County
# 6                                              01003     AL  Baldwin County
# 7                                              01005     AL  Barbour County
# 8                                              01007     AL     Bibb County
# 9                                              01009     AL   Blount County
#
# 2 2003 Rural-urban Continuum Code 2003 Urban Influence Code  \
# 5                               2                         2
# 6                               4                         5
# 7                               6                         6
# 8                               1                         1
# 9                               1                         1
#
# 2 2013 Rural-urban Continuum Code 2013 Urban Influence Code  \
# 5                               2                         2
# 6                               3                         2
# 7                               6                         6
# 8                               1                         1
# 9                               1                         1
#
# 2 Less than a high school diploma, 1970 High school diploma only, 1970  \
# 5                                  6611                           3757
# 6                                 18726                           8426
# 7                                  8120                           2242
# 8                                  5272                           1402
# 9                                 10677                           3440
#
# 2 Some college (1-3 years), 1970  ...  \
# 5                            933  ...
# 6                           2334  ...
# 7                            581  ...
# 8                            238  ...
# 9                            626  ...
#
# 2 Percent of adults with a bachelor's degree or higher, 2008-12  \
# 5                                            21.7078
# 6                                            27.7416
# 7                                            14.5243
# 8                                              8.996
# 9                                            12.3815
#
# 2 Less than a high school diploma, 2017-21 High school diploma only, 2017-21  \
# 5                                     4126                             12977
# 6                                    14555                             44342
# 7                                     4378                              6600
# 8                                     3125                              7052
# 9                                     6650                             14284
#
# 2 Some college or associate's degree, 2017-21  \
# 5                                       11367
# 6                                       50518
# 7                                        5010
# 8                                        3967
# 9                                       13673
#
# 2 Bachelor's degree or higher, 2017-21  \
# 5                                11144
# 6                                52562
# 7                                 2007
# 8                                 1913
# 9                                 6061
#
# 2 Percent of adults with less than a high school diploma, 2017-21  \
# 5                                            10.4155
# 6                                            8.98584
# 7                                             24.329
# 8                                            19.4619
# 9                                            16.3519
#
# 2 Percent of adults with a high school diploma only, 2017-21  \
# 5                                            32.7586
# 6                                            27.3755
# 7                                            36.6769
# 8                                            43.9185
# 9                                            35.1234
#
# 2 Percent of adults completing some college or associate's degree, 2017-21  \
# 5                                            28.6944
# 6                                            31.1884
# 7                                            27.8411
# 8                                            24.7057
# 9                                             33.621
#
# 2 Percent of adults with a bachelor's degree or higher, 2017-21  \
# 5                                            28.1315
# 6                                            32.4503
# 7                                            11.1531
# 8                                            11.9138
# 9                                            14.9036
#
# 2   County_with_State
# 5  Autauga County, AL
# 6  Baldwin County, AL
# 7  Barbour County, AL
# 8     Bibb County, AL
# 9   Blount County, AL
#
# [5 rows x 56 columns]

# %%
education.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3118 entries, 5 to 3208
# Data columns (total 56 columns):
#  #   Column                                                                    Non-Null Count  Dtype
# ---  ------                                                                    --------------  -----
#  0   Federal Information Processing Standard (FIPS) Code                       3118 non-null   object
#  1   State                                                                     3118 non-null   object
#  2   Area name                                                                 3118 non-null   object
#  3   2003 Rural-urban Continuum Code                                           3116 non-null   object
#  4   2003 Urban Influence Code                                                 3116 non-null   object
#  5   2013 Rural-urban Continuum Code                                           3114 non-null   object
#  6   2013 Urban Influence Code                                                 3114 non-null   object
#  7   Less than a high school diploma, 1970                                     3111 non-null   object
#  8   High school diploma only, 1970                                            3111 non-null   object
#  9   Some college (1-3 years), 1970                                            3111 non-null   object
#  10  Four years of college or higher, 1970                                     3111 non-null   object
#  11  Percent of adults with less than a high school diploma, 1970              3111 non-null   object
#  12  Percent of adults with a high school diploma only, 1970                   3111 non-null   object
#  13  Percent of adults completing some college (1-3 years), 1970               3111 non-null   object
#  14  Percent of adults completing four years of college or higher, 1970        3111 non-null   object
#  15  Less than a high school diploma, 1980                                     3115 non-null   object
#  16  High school diploma only, 1980                                            3115 non-null   object
#  17  Some college (1-3 years), 1980                                            3115 non-null   object
#  18  Four years of college or higher, 1980                                     3115 non-null   object
#  19  Percent of adults with less than a high school diploma, 1980              3115 non-null   object
#  20  Percent of adults with a high school diploma only, 1980                   3115 non-null   object
#  21  Percent of adults completing some college (1-3 years), 1980               3115 non-null   object
#  22  Percent of adults completing four years of college or higher, 1980        3115 non-null   object
#  23  Less than a high school diploma, 1990                                     3117 non-null   object
#  24  High school diploma only, 1990                                            3117 non-null   object
#  25  Some college or associate's degree, 1990                                  3117 non-null   object
#  26  Bachelor's degree or higher, 1990                                         3117 non-null   object
#  27  Percent of adults with less than a high school diploma, 1990              3117 non-null   object
#  28  Percent of adults with a high school diploma only, 1990                   3117 non-null   object
#  29  Percent of adults completing some college or associate's degree, 1990     3116 non-null   object
#  30  Percent of adults with a bachelor's degree or higher, 1990                3117 non-null   object
#  31  Less than a high school diploma, 2000                                     3116 non-null   object
#  32  High school diploma only, 2000                                            3116 non-null   object
#  33  Some college or associate's degree, 2000                                  3116 non-null   object
#  34  Bachelor's degree or higher, 2000                                         3116 non-null   object
#  35  Percent of adults with less than a high school diploma, 2000              3116 non-null   object
#  36  Percent of adults with a high school diploma only, 2000                   3116 non-null   object
#  37  Percent of adults completing some college or associate's degree, 2000     3116 non-null   object
#  38  Percent of adults with a bachelor's degree or higher, 2000                3116 non-null   object
#  39  Less than a high school diploma, 2008-12                                  3116 non-null   object
#  40  High school diploma only, 2008-12                                         3116 non-null   object
#  41  Some college or associate's degree, 2008-12                               3116 non-null   object
#  42  Bachelor's degree or higher, 2008-12                                      3116 non-null   object
#  43  Percent of adults with less than a high school diploma, 2008-12           3116 non-null   object
#  44  Percent of adults with a high school diploma only, 2008-12                3116 non-null   object
#  45  Percent of adults completing some college or associate's degree, 2008-12  3116 non-null   object
#  46  Percent of adults with a bachelor's degree or higher, 2008-12             3116 non-null   object
#  47  Less than a high school diploma, 2017-21                                  3115 non-null   object
#  48  High school diploma only, 2017-21                                         3115 non-null   object
#  49  Some college or associate's degree, 2017-21                               3115 non-null   object
#  50  Bachelor's degree or higher, 2017-21                                      3115 non-null   object
#  51  Percent of adults with less than a high school diploma, 2017-21           3115 non-null   object
#  52  Percent of adults with a high school diploma only, 2017-21                3115 non-null   object
#  53  Percent of adults completing some college or associate's degree, 2017-21  3115 non-null   object
#  54  Percent of adults with a bachelor's degree or higher, 2017-21             3115 non-null   object
#  55  County_with_State                                                         3118 non-null   object
# dtypes: object(56)
# memory usage: 1.4+ MB

# %%
check_overlap(df, education, "County_with_State")
# Out:
# (County_with_State              _merge
#  Yellowstone National Park, MT  right_only    1
#  Lousiana, LA                   right_only    1
#  La Salle County, IL            right_only    1
#  Kalawao County, HI             right_only    1
#  Clifton Forge city, VA         right_only    1
#  Bedford city, VA               right_only    1
#  dtype: int64,
#  County_with_State   _merge
#  LaSalle County, IL  left_only    1
#  dtype: int64)

# %%
df[df["County_with_State"] == "Bedford City, VA"]
# Out:
# Empty DataFrame
# Columns: [per_gop, per_dem, per_third_party, County_with_State, Date, Completeness_pct, Metro_status, SVI_CTGY, Census2019, PCTPOVALL_2021, MEDHHINC_2021, WA, BA, IA, AAPI, MEDIAN_AGE_TOT]
# Index: []

# %%
df[df["County_with_State"] == "Clifton Forge City, VA"]
# Out:
# Empty DataFrame
# Columns: [per_gop, per_dem, per_third_party, County_with_State, Date, Completeness_pct, Metro_status, SVI_CTGY, Census2019, PCTPOVALL_2021, MEDHHINC_2021, WA, BA, IA, AAPI, MEDIAN_AGE_TOT]
# Index: []

# %%
education = education[(education["County_with_State"] != "Bedford city, VA") & (education["County_with_State"] != "Clifton Forge city, VA") & (education["County_with_State"] != "Lousiana, LA") & (education["County_with_State"] != "Yellowstone National Park, MT")]
education.replace("La Salle County, IL", "LaSalle County, IL", inplace=True)
education
# Out:
# 2    Federal Information Processing Standard (FIPS) Code State  \
# 5                                                 01001     AL
# 6                                                 01003     AL
# 7                                                 01005     AL
# 8                                                 01007     AL
# 9                                                 01009     AL
# ...                                                 ...    ...
# 3204                                              56037     WY
# 3205                                              56039     WY
# 3206                                              56041     WY
# 3207                                              56043     WY
# 3208                                              56045     WY
#
# 2             Area name  2003 Rural-urban Continuum Code  \
# 5        Autauga County                              2.0
# 6        Baldwin County                              4.0
# 7        Barbour County                              6.0
# 8           Bibb County                              1.0
# 9         Blount County                              1.0
# ...                 ...                              ...
# 3204  Sweetwater County                              5.0
# 3205       Teton County                              7.0
# 3206       Uinta County                              7.0
# 3207    Washakie County                              7.0
# 3208      Weston County                              7.0
#
# 2     2003 Urban Influence Code  2013 Rural-urban Continuum Code  \
# 5                           2.0                              2.0
# 6                           5.0                              3.0
# 7                           6.0                              6.0
# 8                           1.0                              1.0
# 9                           1.0                              1.0
# ...                         ...                              ...
# 3204                        8.0                              5.0
# 3205                        8.0                              7.0
# 3206                        8.0                              7.0
# 3207                       11.0                              7.0
# 3208                        9.0                              7.0
#
# 2     2013 Urban Influence Code  Less than a high school diploma, 1970  \
# 5                           2.0                                 6611.0
# 6                           2.0                                18726.0
# 7                           6.0                                 8120.0
# 8                           1.0                                 5272.0
# 9                           1.0                                10677.0
# ...                         ...                                    ...
# 3204                        8.0                                 4393.0
# 3205                        8.0                                  708.0
# 3206                        8.0                                 1569.0
# 3207                       11.0                                 1572.0
# 3208                        9.0                                 1428.0
#
# 2     High school diploma only, 1970  Some college (1-3 years), 1970  ...  \
# 5                             3757.0                           933.0  ...
# 6                             8426.0                          2334.0  ...
# 7                             2242.0                           581.0  ...
# 8                             1402.0                           238.0  ...
# 9                             3440.0                           626.0  ...
# ...                              ...                             ...  ...
# 3204                          3731.0                           986.0  ...
# 3205                           908.0                           524.0  ...
# 3206                          1517.0                           445.0  ...
# 3207                          1437.0                           590.0  ...
# 3208                          1247.0                           398.0  ...
#
# 2     Percent of adults with a bachelor's degree or higher, 2008-12  \
# 5                                             21.707831
# 6                                             27.741591
# 7                                             14.524286
# 8                                              8.996005
# 9                                             12.381469
# ...                                                 ...
# 3204                                          17.006235
# 3205                                          48.994399
# 3206                                          18.272985
# 3207                                          23.339826
# 3208                                          17.492946
#
# 2     Less than a high school diploma, 2017-21  \
# 5                                         4126
# 6                                        14555
# 7                                         4378
# 8                                         3125
# 9                                         6650
# ...                                        ...
# 3204                                      2029
# 3205                                       701
# 3206                                       851
# 3207                                       320
# 3208                                       348
#
# 2     High school diploma only, 2017-21  \
# 5                                 12977
# 6                                 44342
# 7                                  6600
# 8                                  7052
# 9                                 14284
# ...                                 ...
# 3204                               9069
# 3205                               2984
# 3206                               4820
# 3207                               1391
# 3208                               1826
#
# 2     Some college or associate's degree, 2017-21  \
# 5                                           11367
# 6                                           50518
# 7                                            5010
# 8                                            3967
# 9                                           13673
# ...                                           ...
# 3204                                        11324
# 3205                                         3755
# 3206                                         5186
# 3207                                         2293
# 3208                                         1818
#
# 2     Bachelor's degree or higher, 2017-21  \
# 5                                    11144
# 6                                    52562
# 7                                     2007
# 8                                     1913
# 9                                     6061
# ...                                    ...
# 3204                                  5394
# 3205                                 10219
# 3206                                  2376
# 3207                                  1419
# 3208                                   900
#
# 2     Percent of adults with less than a high school diploma, 2017-21  \
# 5                                             10.415510
# 6                                              8.985844
# 7                                             24.328980
# 8                                             19.461917
# 9                                             16.351923
# ...                                                 ...
# 3204                                           7.294363
# 3205                                           3.969647
# 3206                                           6.430892
# 3207                                           5.900793
# 3208                                           7.113655
#
# 2     Percent of adults with a high school diploma only, 2017-21  \
# 5                                             32.758621
# 6                                             27.375492
# 7                                             36.676855
# 8                                             43.918540
# 9                                             35.123439
# ...                                                 ...
# 3204                                          32.603538
# 3205                                          16.897899
# 3206                                          36.424091
# 3207                                          25.650009
# 3208                                          37.326247
#
# 2     Percent of adults completing some college or associate's degree, 2017-21  \
# 5                                             28.694401
# 6                                             31.188379
# 7                                             27.841067
# 8                                             24.705736
# 9                                             33.621029
# ...                                                 ...
# 3204                                          40.710383
# 3205                                          21.263945
# 3206                                          39.189904
# 3207                                          42.282869
# 3208                                          37.162715
#
# 2     Percent of adults with a bachelor's degree or higher, 2017-21  \
# 5                                             28.131469
# 6                                             32.450286
# 7                                             11.153098
# 8                                             11.913807
# 9                                             14.903610
# ...                                                 ...
# 3204                                          19.391717
# 3205                                          57.868509
# 3206                                          17.955112
# 3207                                          26.166329
# 3208                                          18.397383
#
# 2         County_with_State
# 5        Autauga County, AL
# 6        Baldwin County, AL
# 7        Barbour County, AL
# 8           Bibb County, AL
# 9         Blount County, AL
# ...                     ...
# 3204  Sweetwater County, WY
# 3205       Teton County, WY
# 3206       Uinta County, WY
# 3207    Washakie County, WY
# 3208      Weston County, WY
#
# [3114 rows x 56 columns]

# %%
check_overlap(df, education, "County_with_State")
# Out:
# (County_with_State   _merge
#  Kalawao County, HI  right_only    1
#  dtype: int64,
#  Series([], dtype: int64))

# %%
# creating columns
education['through_hs'] = education['Percent of adults with less than a high school diploma, 2017-21'] + education['Percent of adults with a high school diploma only, 2017-21']
education['through_hs'].astype(int)
education['through_hs'] = round(education['through_hs'], 1)
education['college_up']= education["Percent of adults completing some college or associate's degree, 2017-21"] + education["Percent of adults with a bachelor's degree or higher, 2017-21"]
education['college_up'].astype(int)
education['college_up'] = round(education['college_up'], 1)

"""
 51  Percent of adults with less than a high school diploma, 2017-21           3115 non-null   object
 52  Percent of adults with a high school diploma only, 2017-21                3115 non-null   object
 53  Percent of adults completing some college or associate's degree, 2017-21  3115 non-null   object
 54  Percent of adults with a bachelor's degree or higher, 2017-21   

"""
education
# Out:
# 2    Federal Information Processing Standard (FIPS) Code State  \
# 5                                                 01001     AL
# 6                                                 01003     AL
# 7                                                 01005     AL
# 8                                                 01007     AL
# 9                                                 01009     AL
# ...                                                 ...    ...
# 3204                                              56037     WY
# 3205                                              56039     WY
# 3206                                              56041     WY
# 3207                                              56043     WY
# 3208                                              56045     WY
#
# 2             Area name  2003 Rural-urban Continuum Code  \
# 5        Autauga County                              2.0
# 6        Baldwin County                              4.0
# 7        Barbour County                              6.0
# 8           Bibb County                              1.0
# 9         Blount County                              1.0
# ...                 ...                              ...
# 3204  Sweetwater County                              5.0
# 3205       Teton County                              7.0
# 3206       Uinta County                              7.0
# 3207    Washakie County                              7.0
# 3208      Weston County                              7.0
#
# 2     2003 Urban Influence Code  2013 Rural-urban Continuum Code  \
# 5                           2.0                              2.0
# 6                           5.0                              3.0
# 7                           6.0                              6.0
# 8                           1.0                              1.0
# 9                           1.0                              1.0
# ...                         ...                              ...
# 3204                        8.0                              5.0
# 3205                        8.0                              7.0
# 3206                        8.0                              7.0
# 3207                       11.0                              7.0
# 3208                        9.0                              7.0
#
# 2     2013 Urban Influence Code  Less than a high school diploma, 1970  \
# 5                           2.0                                 6611.0
# 6                           2.0                                18726.0
# 7                           6.0                                 8120.0
# 8                           1.0                                 5272.0
# 9                           1.0                                10677.0
# ...                         ...                                    ...
# 3204                        8.0                                 4393.0
# 3205                        8.0                                  708.0
# 3206                        8.0                                 1569.0
# 3207                       11.0                                 1572.0
# 3208                        9.0                                 1428.0
#
# 2     High school diploma only, 1970  Some college (1-3 years), 1970  ...  \
# 5                             3757.0                           933.0  ...
# 6                             8426.0                          2334.0  ...
# 7                             2242.0                           581.0  ...
# 8                             1402.0                           238.0  ...
# 9                             3440.0                           626.0  ...
# ...                              ...                             ...  ...
# 3204                          3731.0                           986.0  ...
# 3205                           908.0                           524.0  ...
# 3206                          1517.0                           445.0  ...
# 3207                          1437.0                           590.0  ...
# 3208                          1247.0                           398.0  ...
#
# 2     High school diploma only, 2017-21  \
# 5                                 12977
# 6                                 44342
# 7                                  6600
# 8                                  7052
# 9                                 14284
# ...                                 ...
# 3204                               9069
# 3205                               2984
# 3206                               4820
# 3207                               1391
# 3208                               1826
#
# 2     Some college or associate's degree, 2017-21  \
# 5                                           11367
# 6                                           50518
# 7                                            5010
# 8                                            3967
# 9                                           13673
# ...                                           ...
# 3204                                        11324
# 3205                                         3755
# 3206                                         5186
# 3207                                         2293
# 3208                                         1818
#
# 2     Bachelor's degree or higher, 2017-21  \
# 5                                    11144
# 6                                    52562
# 7                                     2007
# 8                                     1913
# 9                                     6061
# ...                                    ...
# 3204                                  5394
# 3205                                 10219
# 3206                                  2376
# 3207                                  1419
# 3208                                   900
#
# 2     Percent of adults with less than a high school diploma, 2017-21  \
# 5                                             10.415510
# 6                                              8.985844
# 7                                             24.328980
# 8                                             19.461917
# 9                                             16.351923
# ...                                                 ...
# 3204                                           7.294363
# 3205                                           3.969647
# 3206                                           6.430892
# 3207                                           5.900793
# 3208                                           7.113655
#
# 2     Percent of adults with a high school diploma only, 2017-21  \
# 5                                             32.758621
# 6                                             27.375492
# 7                                             36.676855
# 8                                             43.918540
# 9                                             35.123439
# ...                                                 ...
# 3204                                          32.603538
# 3205                                          16.897899
# 3206                                          36.424091
# 3207                                          25.650009
# 3208                                          37.326247
#
# 2     Percent of adults completing some college or associate's degree, 2017-21  \
# 5                                             28.694401
# 6                                             31.188379
# 7                                             27.841067
# 8                                             24.705736
# 9                                             33.621029
# ...                                                 ...
# 3204                                          40.710383
# 3205                                          21.263945
# 3206                                          39.189904
# 3207                                          42.282869
# 3208                                          37.162715
#
# 2     Percent of adults with a bachelor's degree or higher, 2017-21  \
# 5                                             28.131469
# 6                                             32.450286
# 7                                             11.153098
# 8                                             11.913807
# 9                                             14.903610
# ...                                                 ...
# 3204                                          19.391717
# 3205                                          57.868509
# 3206                                          17.955112
# 3207                                          26.166329
# 3208                                          18.397383
#
# 2         County_with_State  through_hs  college_up
# 5        Autauga County, AL        43.2        56.8
# 6        Baldwin County, AL        36.4        63.6
# 7        Barbour County, AL        61.0        39.0
# 8           Bibb County, AL        63.4        36.6
# 9         Blount County, AL        51.5        48.5
# ...                     ...         ...         ...
# 3204  Sweetwater County, WY        39.9        60.1
# 3205       Teton County, WY        20.9        79.1
# 3206       Uinta County, WY        42.9        57.1
# 3207    Washakie County, WY        31.6        68.4
# 3208      Weston County, WY        44.4        55.6
#
# [3114 rows x 58 columns]

# %%
education = education[['County_with_State', 'through_hs', 'college_up']]

# %%
education.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3114 entries, 5 to 3208
# Data columns (total 3 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   County_with_State  3114 non-null   object
#  1   through_hs         3114 non-null   float64
#  2   college_up         3114 non-null   float64
# dtypes: float64(2), object(1)
# memory usage: 97.3+ KB

# %%
check = education[education['County_with_State'] == "Kalawao County, HI"]
check
# Out:
# 2     County_with_State  through_hs  college_up
# 573  Kalawao County, HI        34.0        66.0

# %%
check_overlap(df, education, 'County_with_State')
# Out:
# (County_with_State   _merge
#  Kalawao County, HI  right_only    1
#  dtype: int64,
#  Series([], dtype: int64))

# %%
# Making the combined df

df = pd.merge(df, education, how="inner", on="County_with_State")
df
# Out:
#       per_gop  per_dem  per_third_party      County_with_State        Date  \
# 0        71.4     27.0              1.5     Autauga County, AL  05/10/2023
# 1        76.2     22.4              1.4     Baldwin County, AL  05/10/2023
# 2        53.5     45.8              0.8     Barbour County, AL  05/10/2023
# 3        78.4     20.7              0.9        Bibb County, AL  05/10/2023
# 4        89.6      9.6              0.9      Blount County, AL  05/10/2023
# ...       ...      ...              ...                    ...         ...
# 3108     73.7     23.0              3.3  Sweetwater County, WY  05/10/2023
# 3109     29.6     67.1              3.3       Teton County, WY  05/10/2023
# 3110     79.7     16.9              3.4       Uinta County, WY  05/10/2023
# 3111     80.9     16.2              2.9    Washakie County, WY  05/10/2023
# 3112     87.7     10.2              2.1      Weston County, WY  05/10/2023
#
#       Completeness_pct Metro_status SVI_CTGY  Census2019 PCTPOVALL_2021  \
# 0                 92.6        Metro        C     55869.0           10.7
# 1                 92.6        Metro        B    223234.0           10.8
# 2                 92.6    Non-metro        D     24686.0             23
# 3                 92.6        Metro        D     22394.0           20.6
# 4                 92.6        Metro        C     57826.0             12
# ...                ...          ...      ...         ...            ...
# 3108              97.1    Non-metro        B     42343.0            9.2
# 3109              97.1    Non-metro        A     23464.0            5.9
# 3110              97.1    Non-metro        B     20226.0            9.4
# 3111              97.1    Non-metro        B      7805.0           10.2
# 3112              97.1    Non-metro        A      6927.0           10.4
#
#      MEDHHINC_2021    WA    BA   IA  AAPI  MEDIAN_AGE_TOT  through_hs  \
# 0            66444  74.8  21.4  0.5   1.3            39.2        43.2
# 1            65658  87.4   8.4  0.8   1.2            44.1        36.4
# 2            38649  49.2  47.7  0.7   0.7            41.5        61.0
# 3            48454  76.5  21.0  0.6   0.4            40.9        63.4
# 4            56894  95.4   1.9  0.6   0.6            41.2        51.5
# ...            ...   ...   ...  ...   ...             ...         ...
# 3108         74677  93.9   1.3  1.5   1.1            37.7        39.9
# 3109        102709  94.2   0.8  1.1   2.0            41.0        20.9
# 3110         70162  95.3   0.7  1.5   0.8            38.0        42.9
# 3111         62176  94.4   0.5  1.7   1.0            44.8        31.6
# 3112         62509  92.8   0.8  2.1   1.5            44.5        44.4
#
#       college_up
# 0           56.8
# 1           63.6
# 2           39.0
# 3           36.6
# 4           48.5
# ...          ...
# 3108        60.1
# 3109        79.1
# 3110        57.1
# 3111        68.4
# 3112        55.6
#
# [3113 rows x 18 columns]

# %%
# gained 3 rows from the last time b/c of Kalawao County

# %%
df.head()
# Out:
#    per_gop  per_dem  per_third_party   County_with_State        Date  \
# 0     71.4     27.0              1.5  Autauga County, AL  05/10/2023
# 1     76.2     22.4              1.4  Baldwin County, AL  05/10/2023
# 2     53.5     45.8              0.8  Barbour County, AL  05/10/2023
# 3     78.4     20.7              0.9     Bibb County, AL  05/10/2023
# 4     89.6      9.6              0.9   Blount County, AL  05/10/2023
#
#    Completeness_pct Metro_status SVI_CTGY  Census2019 PCTPOVALL_2021  \
# 0              92.6        Metro        C     55869.0           10.7
# 1              92.6        Metro        B    223234.0           10.8
# 2              92.6    Non-metro        D     24686.0             23
# 3              92.6        Metro        D     22394.0           20.6
# 4              92.6        Metro        C     57826.0             12
#
#   MEDHHINC_2021    WA    BA   IA  AAPI  MEDIAN_AGE_TOT  through_hs  college_up
# 0         66444  74.8  21.4  0.5   1.3            39.2        43.2        56.8
# 1         65658  87.4   8.4  0.8   1.2            44.1        36.4        63.6
# 2         38649  49.2  47.7  0.7   0.7            41.5        61.0        39.0
# 3         48454  76.5  21.0  0.6   0.4            40.9        63.4        36.6
# 4         56894  95.4   1.9  0.6   0.6            41.2        51.5        48.5

# %%
sns.pairplot(df)

# %% [markdown]
# # Nulls

# %%
df.isna().sum()
# Out:
# per_gop               0
# per_dem               0
# per_third_party       0
# County_with_State     0
# Date                  0
# Completeness_pct     15
# Metro_status          0
# SVI_CTGY              0
# Census2019            0
# PCTPOVALL_2021        0
# MEDHHINC_2021         0
# WA                    0
# BA                    0
# IA                    0
# AAPI                  0
# MEDIAN_AGE_TOT        0
# through_hs            0
# college_up            0
# dtype: int64

# %%
nulls = df[df.isna().any(axis=1)]
nulls

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9339 entries, 0 to 9338
# Data columns (total 19 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   per_gop                9339 non-null   float64
#  1   per_dem                9339 non-null   float64
#  2   per_third_party        9339 non-null   float64
#  3   County_with_State      9339 non-null   object
#  4   Date                   9339 non-null   object
#  5   Completeness_pct       9305 non-null   float64
#  6   Booster_Doses_Vax_Pct  9302 non-null   float64
#  7   Metro_status           9339 non-null   object
#  8   SVI_CTGY               9338 non-null   object
#  9   Census2019             9339 non-null   float64
#  10  PCTPOVALL_2021         9339 non-null   object
#  11  MEDHHINC_2021          9339 non-null   object
#  12  WA                     9339 non-null   float64
#  13  BA                     9339 non-null   float64
#  14  IA                     9339 non-null   float64
#  15  AAPI                   9339 non-null   float64
#  16  MEDIAN_AGE_TOT         9339 non-null   float64
#  17  through_hs             9339 non-null   float64
#  18  college_up             9339 non-null   float64
# dtypes: float64(13), object(6)
# memory usage: 1.4+ MB

# %%
df.head()
# Out:
#    per_gop  per_dem  per_third_party   County_with_State        Date  \
# 0     71.4     27.0              1.5  Autauga County, AL  05/10/2023
# 1     71.4     27.0              1.5  Autauga County, AL  12/28/2022
# 2     71.4     27.0              1.5  Autauga County, AL  12/31/2021
# 3     76.2     22.4              1.4  Baldwin County, AL  05/10/2023
# 4     76.2     22.4              1.4  Baldwin County, AL  12/28/2022
#
#    Completeness_pct  Booster_Doses_Vax_Pct Metro_status SVI_CTGY  Census2019  \
# 0              92.6                   38.0        Metro        C     55869.0
# 1              92.6                   37.6        Metro        C     55869.0
# 2              92.7                   25.8        Metro        B     55869.0
# 3              92.6                   39.9        Metro        B    223234.0
# 4              92.6                   39.4        Metro        B    223234.0
#
#   PCTPOVALL_2021 MEDHHINC_2021    WA    BA   IA  AAPI  MEDIAN_AGE_TOT  \
# 0           10.7         66444  74.8  21.4  0.5   1.3            39.2
# 1           10.7         66444  74.8  21.4  0.5   1.3            39.2
# 2           10.7         66444  74.8  21.4  0.5   1.3            39.2
# 3           10.8         65658  87.4   8.4  0.8   1.2            44.1
# 4           10.8         65658  87.4   8.4  0.8   1.2            44.1
#
#    through_hs  college_up
# 0        43.2        56.8
# 1        43.2        56.8
# 2        43.2        56.8
# 3        36.4        63.6
# 4        36.4        63.6

# %%
nulls[nulls["County_with_State"].str.endswith("CA")]
# Out:
#      per_gop  per_dem  per_third_party    County_with_State        Date  \
# 474     32.9     64.2              2.8    Alpine County, CA  05/10/2023
# 475     32.9     64.2              2.8    Alpine County, CA  12/28/2022
# 510     48.7     48.9              2.4      Inyo County, CA  05/10/2023
# 511     48.7     48.9              2.4      Inyo County, CA  12/28/2022
# 534     57.9     39.8              2.4  Mariposa County, CA  05/10/2023
# 535     57.9     39.8              2.4  Mariposa County, CA  12/28/2022
# 543     71.7     26.5              1.8     Modoc County, CA  05/10/2023
# 544     71.7     26.5              1.8     Modoc County, CA  12/28/2022
# 546     37.3     59.6              3.1      Mono County, CA  05/10/2023
# 547     37.3     59.6              3.1      Mono County, CA  12/28/2022
# 564     57.3     40.5              2.2    Plumas County, CA  05/10/2023
# 565     57.3     40.5              2.2    Plumas County, CA  12/28/2022
# 606     59.2     37.8              3.0    Sierra County, CA  05/10/2023
# 607     59.2     37.8              3.0    Sierra County, CA  12/28/2022
# 627     50.9     45.6              3.5   Trinity County, CA  05/10/2023
# 628     50.9     45.6              3.5   Trinity County, CA  12/28/2022
#
#      Completeness_pct  Booster_Doses_Vax_Pct Metro_status SVI_CTGY  \
# 474               NaN                    NaN    Non-metro        C
# 475               NaN                    NaN    Non-metro        C
# 510               NaN                    NaN    Non-metro        C
# 511               NaN                    NaN    Non-metro        B
# 534               NaN                    NaN    Non-metro        D
# 535               NaN                    NaN    Non-metro        D
# 543               NaN                    NaN    Non-metro        D
# 544               NaN                    NaN    Non-metro        D
# 546               NaN                    NaN    Non-metro        B
# 547               NaN                    NaN    Non-metro        B
# 564               NaN                    NaN    Non-metro        B
# 565               NaN                    NaN    Non-metro        B
# 606               NaN                    NaN    Non-metro        B
# 607               NaN                    NaN    Non-metro        A
# 627               NaN                    NaN    Non-metro        D
# 628               NaN                    NaN    Non-metro        D
#
#      Census2019 PCTPOVALL_2021 MEDHHINC_2021    WA   BA    IA  AAPI  \
# 474      1129.0           15.8         87570  68.9  0.5  23.7   1.9
# 475      1129.0           15.8         87570  68.9  0.5  23.7   1.9
# 510     18039.0           12.8         62381  79.1  1.2  13.8   1.9
# 511     18039.0           12.8         62381  79.1  1.2  13.8   1.9
# 534     17203.0           14.1         60377  88.9  1.3   3.7   2.1
# 535     17203.0           14.1         60377  88.9  1.3   3.7   2.1
# 543      8841.0           19.9         49273  86.9  1.4   5.5   1.8
# 544      8841.0           19.9         49273  86.9  1.4   5.5   1.8
# 546     14444.0            9.8         70945  89.6  1.2   3.0   2.6
# 547     14444.0            9.8         70945  89.6  1.2   3.0   2.6
# 564     18807.0             13         58154  90.3  1.0   3.2   1.3
# 565     18807.0             13         58154  90.3  1.0   3.2   1.3
# 606      3005.0           12.3         60659  92.6  0.5   2.6   1.2
# 607      3005.0           12.3         60659  92.6  0.5   2.6   1.2
# 627     12285.0           19.1         45508  86.0  0.7   5.1   2.9
# 628     12285.0           19.1         45508  86.0  0.7   5.1   2.9
#
#      MEDIAN_AGE_TOT  through_hs  college_up
# 474            47.1        32.0        68.0
# 475            47.1        32.0        68.0
# 510            44.7        38.4        61.6
# 511            44.7        38.4        61.6
# 534            51.0        31.5        68.5
# 535            51.0        31.5        68.5
# 543            50.8        47.1        52.9
# 544            50.8        47.1        52.9
# 546            42.0        35.1        64.9
# 547            42.0        35.1        64.9
# 564            53.2        32.8        67.2
# 565            53.2        32.8        67.2
# 606            53.7        35.2        64.8
# 607            53.7        35.2        64.8
# 627            52.0        44.5        55.5
# 628            52.0        44.5        55.5

# %% [markdown]
# Can't impute data with dataset mean! That's data leakage

# %%
for index, row in df.iterrows():
    if row['County_with_State'] in nulls[nulls["County_with_State"].str.endswith("CA")]:
        row['Completeness_pct'] = df[df["County_with_State"].str.endswith("CA")]["Completeness_pct"].mean()
        row['Booster_Doses_Vax_Pct'] = df[df["County_with_State"].str.endswith("CA")]["Booster_Doses_Vax_Pct"].mean()

# %%
nulls
# Out:
#       per_gop  per_dem  per_third_party      County_with_State        Date  \
# 474      32.9     64.2              2.8      Alpine County, CA  05/10/2023
# 475      32.9     64.2              2.8      Alpine County, CA  12/28/2022
# 510      48.7     48.9              2.4        Inyo County, CA  05/10/2023
# 511      48.7     48.9              2.4        Inyo County, CA  12/28/2022
# 534      57.9     39.8              2.4    Mariposa County, CA  05/10/2023
# 535      57.9     39.8              2.4    Mariposa County, CA  12/28/2022
# 543      71.7     26.5              1.8       Modoc County, CA  05/10/2023
# 544      71.7     26.5              1.8       Modoc County, CA  12/28/2022
# 546      37.3     59.6              3.1        Mono County, CA  05/10/2023
# 547      37.3     59.6              3.1        Mono County, CA  12/28/2022
# 564      57.3     40.5              2.2      Plumas County, CA  05/10/2023
# 565      57.3     40.5              2.2      Plumas County, CA  12/28/2022
# 606      59.2     37.8              3.0      Sierra County, CA  05/10/2023
# 607      59.2     37.8              3.0      Sierra County, CA  12/28/2022
# 627      50.9     45.6              3.5     Trinity County, CA  05/10/2023
# 628      50.9     45.6              3.5     Trinity County, CA  12/28/2022
# 1554     30.6     66.9              2.5      Hawaii County, HI  05/10/2023
# 1555     30.6     66.9              2.5      Hawaii County, HI  12/28/2022
# 1556     30.6     66.9              2.5      Hawaii County, HI  12/31/2021
# 1557     35.7     62.5              1.8    Honolulu County, HI  05/10/2023
# 1558     35.7     62.5              1.8    Honolulu County, HI  12/28/2022
# 1559     35.7     62.5              1.8    Honolulu County, HI  12/31/2021
# 1560     34.6     63.4              2.1       Kauai County, HI  05/10/2023
# 1561     34.6     63.4              2.1       Kauai County, HI  12/28/2022
# 1562     34.6     63.4              2.1       Kauai County, HI  12/31/2021
# 1563     31.1     66.6              2.3        Maui County, HI  05/10/2023
# 1564     31.1     66.6              2.3        Maui County, HI  12/28/2022
# 1565     31.1     66.6              2.3        Maui County, HI  12/31/2021
# 3564     36.8     61.2              2.0  Barnstable County, MA  05/10/2023
# 3565     36.8     61.2              2.0  Barnstable County, MA  12/28/2022
# 3566     36.8     61.2              2.0  Barnstable County, MA  12/31/2021
# 3573     20.6     77.5              2.0       Dukes County, MA  05/10/2023
# 3574     20.6     77.5              2.0       Dukes County, MA  12/28/2022
# 3575     20.6     77.5              2.0       Dukes County, MA  12/31/2021
# 3591     26.2     71.7              2.1   Nantucket County, MA  05/10/2023
# 3592     26.2     71.7              2.1   Nantucket County, MA  12/28/2022
# 3593     26.2     71.7              2.1   Nantucket County, MA  12/31/2021
# 5363     32.5     66.1              1.4  Rio Arriba County, NM  12/31/2021
#
#       Completeness_pct  Series_Complete_18PlusPop_Pct  Booster_Doses_Vax_Pct  \
# 474                NaN                            NaN                    NaN
# 475                NaN                            NaN                    NaN
# 510                NaN                            NaN                    NaN
# 511                NaN                            NaN                    NaN
# 534                NaN                            NaN                    NaN
# 535                NaN                            NaN                    NaN
# 543                NaN                            NaN                    NaN
# 544                NaN                            NaN                    NaN
# 546                NaN                            NaN                    NaN
# 547                NaN                            NaN                    NaN
# 564                NaN                            NaN                    NaN
# 565                NaN                            NaN                    NaN
# 606                NaN                            NaN                    NaN
# 607                NaN                            NaN                    NaN
# 627                NaN                            NaN                    NaN
# 628                NaN                            NaN                    NaN
# 1554               NaN                            NaN                    NaN
# 1555               NaN                            NaN                    NaN
# 1556               NaN                            NaN                    NaN
# 1557               NaN                            NaN                    NaN
# 1558               NaN                            NaN                    NaN
# 1559               NaN                            NaN                    NaN
# 1560               NaN                            NaN                    NaN
# 1561               NaN                            NaN                    NaN
# 1562               NaN                            NaN                    NaN
# 1563               NaN                            NaN                    NaN
# 1564               NaN                            NaN                    NaN
# 1565               NaN                            NaN                    NaN
# 3564               NaN                            NaN                    NaN
# 3565               NaN                            NaN                    NaN
# 3566              89.9                            NaN                    NaN
# 3573               NaN                            NaN                    NaN
# 3574               NaN                            NaN                    NaN
# 3575              89.9                            NaN                    NaN
# 3591               NaN                            NaN                    NaN
# 3592               NaN                            NaN                    NaN
# 3593              89.9                            NaN                    NaN
# 5363              97.2                           85.9                   38.3
#
#       Booster_Doses_18Plus_Vax_Pct Metro_status  ... Census2019_18PlusPop  \
# 474                            NaN    Non-metro  ...                929.0
# 475                            NaN    Non-metro  ...                929.0
# 510                            NaN    Non-metro  ...              14312.0
# 511                            NaN    Non-metro  ...              14312.0
# 534                            NaN    Non-metro  ...              14425.0
# 535                            NaN    Non-metro  ...              14425.0
# 543                            NaN    Non-metro  ...               7122.0
# 544                            NaN    Non-metro  ...               7122.0
# 546                            NaN    Non-metro  ...              11875.0
# 547                            NaN    Non-metro  ...              11875.0
# 564                            NaN    Non-metro  ...              15537.0
# 565                            NaN    Non-metro  ...              15537.0
# 606                            NaN    Non-metro  ...               2509.0
# 607                            NaN    Non-metro  ...               2509.0
# 627                            NaN    Non-metro  ...              10154.0
# 628                            NaN    Non-metro  ...              10154.0
# 1554                           NaN    Non-metro  ...             158312.0
# 1555                           NaN    Non-metro  ...             158312.0
# 1556                           NaN    Non-metro  ...             158312.0
# 1557                           NaN        Metro  ...             769692.0
# 1558                           NaN        Metro  ...             769692.0
# 1559                           NaN        Metro  ...             769692.0
# 1560                           NaN    Non-metro  ...              56631.0
# 1561                           NaN    Non-metro  ...              56631.0
# 1562                           NaN    Non-metro  ...              56631.0
# 1563                           NaN        Metro  ...             131283.0
# 1564                           NaN        Metro  ...             131283.0
# 1565                           NaN        Metro  ...             131283.0
# 3564                           NaN        Metro  ...             181374.0
# 3565                           NaN        Metro  ...             181374.0
# 3566                           NaN        Metro  ...             181374.0
# 3573                           NaN    Non-metro  ...              14247.0
# 3574                           NaN    Non-metro  ...              14247.0
# 3575                           NaN    Non-metro  ...              14247.0
# 3591                           NaN    Non-metro  ...               9029.0
# 3592                           NaN    Non-metro  ...               9029.0
# 3593                           NaN    Non-metro  ...               9029.0
# 5363                          42.8    Non-metro  ...              29944.0
#
#       PCTPOVALL_2021  MEDHHINC_2021    WA    BA    IA  AAPI  MEDIAN_AGE_TOT  \
# 474             15.8          87570  68.9   0.5  23.7   1.9            47.1
# 475             15.8          87570  68.9   0.5  23.7   1.9            47.1
# 510             12.8          62381  79.1   1.2  13.8   1.9            44.7
# 511             12.8          62381  79.1   1.2  13.8   1.9            44.7
# 534             14.1          60377  88.9   1.3   3.7   2.1            51.0
# 535             14.1          60377  88.9   1.3   3.7   2.1            51.0
# 543             19.9          49273  86.9   1.4   5.5   1.8            50.8
# 544             19.9          49273  86.9   1.4   5.5   1.8            50.8
# 546              9.8          70945  89.6   1.2   3.0   2.6            42.0
# 547              9.8          70945  89.6   1.2   3.0   2.6            42.0
# 564               13          58154  90.3   1.0   3.2   1.3            53.2
# 565               13          58154  90.3   1.0   3.2   1.3            53.2
# 606             12.3          60659  92.6   0.5   2.6   1.2            53.7
# 607             12.3          60659  92.6   0.5   2.6   1.2            53.7
# 627             19.1          45508  86.0   0.7   5.1   2.9            52.0
# 628             19.1          45508  86.0   0.7   5.1   2.9            52.0
# 1554            14.7          67896  34.4   0.9   0.6  33.1            43.5
# 1555            14.7          67896  34.4   0.9   0.6  33.1            43.5
# 1556            14.7          67896  34.4   0.9   0.6  33.1            43.5
# 1557              10          90176  21.2   2.8   0.3  52.5            39.6
# 1558              10          90176  21.2   2.8   0.3  52.5            39.6
# 1559              10          90176  21.2   2.8   0.3  52.5            39.6
# 1560            11.2          76719  32.7   0.8   0.5  39.4            43.1
# 1561            11.2          76719  32.7   0.8   0.5  39.4            43.1
# 1562            11.2          76719  32.7   0.8   0.5  39.4            43.1
# 1563            11.4          75421  34.6   0.9   0.6  39.0            42.9
# 1564            11.4          75421  34.6   0.9   0.6  39.0            42.9
# 1565            11.4          75421  34.6   0.9   0.6  39.0            42.9
# 3564               8          82980  91.8   3.8   0.7   1.8            55.6
# 3565               8          82980  91.8   3.8   0.7   1.8            55.6
# 3566               8          82980  91.8   3.8   0.7   1.8            55.6
# 3573             7.6          79338  89.2   5.2   1.2   1.5            49.8
# 3574             7.6          79338  89.2   5.2   1.2   1.5            49.8
# 3575             7.6          79338  89.2   5.2   1.2   1.5            49.8
# 3591             5.9         110966  84.2  11.3   0.5   1.9            41.8
# 3592             5.9         110966  84.2  11.3   0.5   1.9            41.8
# 3593             5.9         110966  84.2  11.3   0.5   1.9            41.8
# 5363            20.4          47042  75.7   1.0  20.2   1.1            42.3
#
#       through_hs  college_up
# 474         32.0        68.0
# 475         32.0        68.0
# 510         38.4        61.6
# 511         38.4        61.6
# 534         31.5        68.5
# 535         31.5        68.5
# 543         47.1        52.9
# 544         47.1        52.9
# 546         35.1        64.9
# 547         35.1        64.9
# 564         32.8        67.2
# 565         32.8        67.2
# 606         35.2        64.8
# 607         35.2        64.8
# 627         44.5        55.5
# 628         44.5        55.5
# 1554        36.6        63.4
# 1555        36.6        63.4
# 1556        36.6        63.4
# 1557        32.8        67.2
# 1558        32.8        67.2
# 1559        32.8        67.2
# 1560        37.5        62.5
# 1561        37.5        62.5
# 1562        37.5        62.5
# 1563        37.6        62.4
# 1564        37.6        62.4
# 1565        37.6        62.4
# 3564        26.6        73.4
# 3565        26.6        73.4
# 3566        26.6        73.4
# 3573        29.6        70.4
# 3574        29.6        70.4
# 3575        29.6        70.4
# 3591        22.0        78.0
# 3592        22.0        78.0
# 3593        22.0        78.0
# 5363        48.9        51.1
#
# [38 rows x 22 columns]

# %%
df['Completeness_pct']

# %%
df['Series_Complete_18PlusPop_Pct']

# %%
df['Booster_Doses_Vax_Pct']

# %%
df['Booster_Doses_18Plus_Vax_Pct']

# %% [markdown]
# # Binning the Target

# %% [markdown]
# # Decision Tree

# %%
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns
from scipy import stats as stats

from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier, plot_tree

from sklearn.metrics import precision_score, recall_score
from sklearn.model_selection import train_test_split, GridSearchCV,\
cross_val_score, RandomizedSearchCV

from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.impute import SimpleImputer
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer

# %%
y = df_2023['Completeness_pct']

# Completeness_pct 
# Series_Complete_18PlusPop_Pct 
# Booster_Doses_Vax_Pct      
# Booster_Doses_18Plus_Vax_Pct

# %%
# Dummy out metro

# %%
sns.pairplot(df_2023)

# %%
sns.set(rc={'figure.figsize':(8, 8)})
sns.heatmap(df_2023.corr(), annot=True);

# %% [markdown]
# # Extras

# %%
ct_data = pd.read_csv('../data/CT_data.csv', encoding="latin-1")
ct_data.head()

# %%
df1 = vaccinations[(vaccinations['FIPS'] == "UNK")]
#df1["Recip_State"].value_counts(normalize=True)
df1

# %%
vaccinations["Recip_County"].value_counts(normalize=True)

# %%
fips_counts = vaccinations["FIPS"].value_counts().reset_index()
fips_counts.drop(index=0, inplace=True)
fips_counts["FIPS"] = fips_counts['FIPS'].astype(int)
fips_counts.sort_values(by="FIPS", inplace=True)
fips_counts
#fips_counts.sort_values(by='FIPS')
#fips_counts..head()


#fips_counts.drop("UNK", axis=0, inplace=True)
#fips_counts = fips_counts.astype(int)
#fips_counts["FIPS"].sort_values(axis=0, inplace=True)
#fips_counts.head()

# %%
fips_counts = election["county_fips"].value_counts().reset_index()
fips_counts.drop(index=0, inplace=True)
fips_counts["county_fips"] = fips_counts['county_fips'].astype(int)
fips_counts.sort_values(by="county_fips", inplace=True)
fips_counts

# %%
census.head(20)

# %% [markdown]
# # Next Steps

# %% [markdown]
# Need more predictors:
# - Vaccine access is a big one, but couldn't find county level hospital or vaccination provider location data
# - Deaths per county: [Johns Jopkins Interactive Map](https://coronavirus.jhu.edu/us-map)
# - Unemployment rate: free time to get shot?
# - Break down further by age? CDC has splits by age
